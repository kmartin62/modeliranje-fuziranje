# %%
# data manipulation
import pandas as pd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt

# math
import numpy as np
import scipy

# %%
folder_path = 'data'

gjorche_stanica = 'gjorche_stanica.csv'

# %%
def read_csv_file_by_location(location):
    return pd.read_csv(f'{folder_path}/{location}', parse_dates=['date_time'], index_col='date_time')

# %%
def get_period_values(dataset, from_date, to_date, feature=None):
    if feature is None:
        return dataset[from_date:to_date]
    return dataset[from_date:to_date][feature]

# %%
def plot_line_figures(df_data):
    plt.figure(figsize=(15,8))
    for elem in df_data:
        sns.lineplot(data=elem)

# %% [markdown]
# ## Gjorche Stanica

# %%
df_gjorche_stanica = read_csv_file_by_location(gjorche_stanica)

# %%
df_pre_covid_pm10 = get_period_values(df_gjorche_stanica, "2020-01-01 00:00:00", "2020-03-01 00:00:00", "pm10")
df_covid_period_pm10 = get_period_values(df_gjorche_stanica, "2020-03-10 00:00:00", "2020-05-20 00:00:00", "pm10")
df_post_covid_period_pm10 = get_period_values(df_gjorche_stanica, "2020-05-20 00:00:00", "2020-08-20 00:00:00", "pm10")

df_covid_period_pm10_last_year = get_period_values(df_gjorche_stanica, "2019-03-10 00:00:00", "2019-05-20 00:00:00", "pm10")

# %%
df_pre_covid_noise = get_period_values(df_gjorche_stanica, "2020-01-01 00:00:00", "2020-03-01 00:00:00", "noise")
df_covid_period_noise = get_period_values(df_gjorche_stanica, "2020-03-10 00:00:00", "2020-05-20 00:00:00", "noise")
df_post_covid_period_noise = get_period_values(df_gjorche_stanica, "2020-05-20 00:00:00", "2020-08-20 00:00:00", "noise")

df_covid_period_noise_last_year = get_period_values(df_gjorche_stanica, "2019-03-10 00:00:00", "2019-05-20 00:00:00", "noise")

# %% [markdown]
# ### Pre-Covid period

# %%
# precovid
plot_line_figures([df_pre_covid_pm10])

# %%
# precovid
plot_line_figures([df_pre_covid_noise])

# %%
# precovid
plot_line_figures([df_pre_covid_pm10, df_pre_covid_noise])

# %% [markdown]
# ### Covid period

# %%
# covid
plot_line_figures([df_covid_period_pm10])

# %%
# covid
plot_line_figures([df_covid_period_noise])

# %%
# covid
plot_line_figures([df_covid_period_pm10, df_covid_period_noise])

# %% [markdown]
# ### Post-Covid period

# %%
# postcovid
plot_line_figures([df_post_covid_period_pm10])

# %%
# postcovid
plot_line_figures([df_post_covid_period_noise])

# %%
# postcovid
plot_line_figures([df_post_covid_period_pm10, df_post_covid_period_noise])

# %% [markdown]
# ### Last year quarantine period

# %%
# last year
plot_line_figures([df_covid_period_pm10_last_year])

# %%
# last year
plot_line_figures([df_covid_period_noise_last_year])

# %%
# last year
plot_line_figures([df_covid_period_pm10_last_year, df_covid_period_noise_last_year])

# %% [markdown]
# ### Correlation and mean

# %%
pm10_np = df_gjorche_stanica['pm10'].to_numpy()
pm10_np = np.where(np.isnan(pm10_np), 0, pm10_np)
noise_np = df_gjorche_stanica['noise'].to_numpy()

# %%
pearsons_coefficient = np.corrcoef(pm10_np, noise_np)
pearsons_coefficient
# Out:
# array([[1.        , 0.23234517],
#        [0.23234517, 1.        ]])

# %%
{"pre_covid_pm10": df_pre_covid_pm10.mean(),
 "covid_period_pm10": df_covid_period_pm10.mean(),
 "last_year_quarantine_period": df_covid_period_pm10_last_year.mean(),
 "post_covid_pm10": df_post_covid_period_pm10.mean()}
# Out:
# {'pre_covid_pm10': 57.44938357353707,
#  'covid_period_pm10': 16.365703388587356,
#  'last_year_quarantine_period': 17.041953938682706,
#  'post_covid_pm10': 8.092617753623188}
