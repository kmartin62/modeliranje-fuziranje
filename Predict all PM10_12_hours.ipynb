# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

import scipy.stats as st
from sklearn import ensemble, tree, linear_model

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError, MeanAbsolutePercentageError
from tensorflow.keras.optimizers import Adam

from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle

# %%
def plot_predictions_zhelezara(model, X, y, y_df_test, start = 0, end = 100):
    predictions = model.predict(X)
    y_df_test = y_df_test[1:]
    
    list_Year = [str(i).split(" ")[0][0:4] for i in list(y_df_test.index)]
    list_YM = [str(i).split(" ")[0][:-3] for i in  list(y_df_test.index)]
    
    fields = ['sensor_id', 'lat', 'log']
    df = pd.DataFrame()
    for elem in files:
        for field in fields:
            df[f'{elem}_{field}'] = y_df_test[f'{elem}_{field}']
    
    for i in range(len(files)):
        df[f'{files[i].capitalize()} PM10 actuals'] = y[:, i]
        df[f'{files[i].capitalize()} PM10 predictions'] = predictions[:, i]

    df['Year'] = list_Year
    df['YM'] = list_YM
    
    la = [f'{elem}_{field}' for elem in files for field in fields]
    la.append('Year')
    la.append('YM')
    
    
    
    lb = [f'{files[i].capitalize()} PM10 actuals' for i in range(len(files))]
    lc = [f'{files[i].capitalize()} PM10 predictions' for i in range(len(files))]
    df_yearly = df.groupby(la).mean()
    df_yearly = df_yearly[lb + lc].reset_index()
    sns.set_style('darkgrid')
    sns.set(rc={'figure.figsize':(14,8)})

    ax = sns.lineplot(data=df_yearly, x ='YM', y = 'Zhelezara PM10 actuals', label = 'Zhelezara PM10 actual values')
    gx = sns.lineplot(data=df_yearly, x ='YM', y = 'Zhelezara PM10 predictions', label = 'Zhelezara PM10 predicted values')


    plt.legend(bbox_to_anchor=(1, 1))
    plt.ylabel('PM10 (µg/m3)')
    plt.xlabel('Year')
    plt.legend(loc="upper left")
    plt.show()
    
def plot_predictions_11_oktomvri(model, X, y, y_df_test, start = 0, end = 100):
    predictions = model.predict(X)
    y_df_test = y_df_test[1:]
    
    list_Year = [str(i).split(" ")[0][0:4] for i in list(y_df_test.index)]
    list_YM = [str(i).split(" ")[0][:-3] for i in  list(y_df_test.index)]
    
    fields = ['sensor_id', 'lat', 'log']
    df = pd.DataFrame()
    for elem in files:
        for field in fields:
            df[f'{elem}_{field}'] = y_df_test[f'{elem}_{field}']
    
    for i in range(len(files)):
        df[f'{files[i].capitalize()} PM10 actuals'] = y[:, i]
        df[f'{files[i].capitalize()} PM10 predictions'] = predictions[:, i]

    df['Year'] = list_Year
    df['YM'] = list_YM
    
    la = [f'{elem}_{field}' for elem in files for field in fields]
    la.append('Year')
    la.append('YM')
    
    
    
    lb = [f'{files[i].capitalize()} PM10 actuals' for i in range(len(files))]
    lc = [f'{files[i].capitalize()} PM10 predictions' for i in range(len(files))]
    df_yearly = df.groupby(la).mean()
    df_yearly = df_yearly[lb + lc].reset_index()
    sns.set_style('darkgrid')
    sns.set(rc={'figure.figsize':(14,8)})
    
    bx = sns.lineplot(data=df_yearly, x ='YM', y = '11_oktomvri PM10 actuals', label = '11 Oktomvri PM10 actual values')
    hx = sns.lineplot(data=df_yearly, x ='YM', y = '11_oktomvri PM10 predictions', label = '11 Oktomvri PM10 actual values')


    plt.legend(bbox_to_anchor=(1, 1))
    plt.ylabel('PM10 (µg/m3)')
    plt.xlabel('Year')
    plt.legend(loc="upper left")
    plt.show()
    
def plot_predictions_sopishte(model, X, y, y_df_test, start = 0, end = 100):
    predictions = model.predict(X)
    y_df_test = y_df_test[1:]
    
    list_Year = [str(i).split(" ")[0][0:4] for i in list(y_df_test.index)]
    list_YM = [str(i).split(" ")[0][:-3] for i in  list(y_df_test.index)]
    
    fields = ['sensor_id', 'lat', 'log']
    df = pd.DataFrame()
    for elem in files:
        for field in fields:
            df[f'{elem}_{field}'] = y_df_test[f'{elem}_{field}']
    
    for i in range(len(files)):
        df[f'{files[i].capitalize()} PM10 actuals'] = y[:, i]
        df[f'{files[i].capitalize()} PM10 predictions'] = predictions[:, i]

    df['Year'] = list_Year
    df['YM'] = list_YM
    
    la = [f'{elem}_{field}' for elem in files for field in fields]
    la.append('Year')
    la.append('YM')
    
    
    
    lb = [f'{files[i].capitalize()} PM10 actuals' for i in range(len(files))]
    lc = [f'{files[i].capitalize()} PM10 predictions' for i in range(len(files))]
    df_yearly = df.groupby(la).mean()
    df_yearly = df_yearly[lb + lc].reset_index()
    sns.set_style('darkgrid')
    sns.set(rc={'figure.figsize':(14,8)})
    
    cx = sns.lineplot(data=df_yearly, x ='YM', y = 'Sopishte PM10 actuals', label = 'Sopishte PM10 actual values')
    jx = sns.lineplot(data=df_yearly, x ='YM', y = 'Sopishte PM10 predictions', label = 'Sopishte PM10 actual values')


    plt.legend(bbox_to_anchor=(1, 1))
    plt.ylabel('PM10 (µg/m3)')
    plt.xlabel('Year')
    plt.legend(loc="upper left")
    plt.show()

def plot_predictions_gjorche_stanica(model, X, y, y_df_test, start = 0, end = 100):
    predictions = model.predict(X)
    y_df_test = y_df_test[1:]
    
    list_Year = [str(i).split(" ")[0][0:4] for i in list(y_df_test.index)]
    list_YM = [str(i).split(" ")[0][:-3] for i in  list(y_df_test.index)]
    
    fields = ['sensor_id', 'lat', 'log']
    df = pd.DataFrame()
    for elem in files:
        for field in fields:
            df[f'{elem}_{field}'] = y_df_test[f'{elem}_{field}']
    
    for i in range(len(files)):
        df[f'{files[i].capitalize()} PM10 actuals'] = y[:, i]
        df[f'{files[i].capitalize()} PM10 predictions'] = predictions[:, i]

    df['Year'] = list_Year
    df['YM'] = list_YM
    
    la = [f'{elem}_{field}' for elem in files for field in fields]
    la.append('Year')
    la.append('YM')
    
    
    
    lb = [f'{files[i].capitalize()} PM10 actuals' for i in range(len(files))]
    lc = [f'{files[i].capitalize()} PM10 predictions' for i in range(len(files))]
    df_yearly = df.groupby(la).mean()
    df_yearly = df_yearly[lb + lc].reset_index()
    sns.set_style('darkgrid')
    sns.set(rc={'figure.figsize':(14,8)})
    
    dx = sns.lineplot(data=df_yearly, x ='YM', y = 'Gjorche_stanica PM10 actuals', label = 'Gjorche_stanica PM10 actual values')
    kx = sns.lineplot(data=df_yearly, x ='YM', y = 'Gjorche_stanica PM10 predictions', label = 'Gjorche_stanica PM10 actual values')


    plt.legend(bbox_to_anchor=(1, 1))
    plt.ylabel('PM10 (µg/m3)')
    plt.xlabel('Year')
    plt.legend(loc="upper left")
    plt.show()

    
def plot_predictions_crniche(model, X, y, y_df_test, start = 0, end = 100):
    predictions = model.predict(X)
    y_df_test = y_df_test[1:]
    
    list_Year = [str(i).split(" ")[0][0:4] for i in list(y_df_test.index)]
    list_YM = [str(i).split(" ")[0][:-3] for i in  list(y_df_test.index)]
    
    fields = ['sensor_id', 'lat', 'log']
    df = pd.DataFrame()
    for elem in files:
        for field in fields:
            df[f'{elem}_{field}'] = y_df_test[f'{elem}_{field}']
    
    for i in range(len(files)):
        df[f'{files[i].capitalize()} PM10 actuals'] = y[:, i]
        df[f'{files[i].capitalize()} PM10 predictions'] = predictions[:, i]

    df['Year'] = list_Year
    df['YM'] = list_YM
    
    la = [f'{elem}_{field}' for elem in files for field in fields]
    la.append('Year')
    la.append('YM')
    
    
    
    lb = [f'{files[i].capitalize()} PM10 actuals' for i in range(len(files))]
    lc = [f'{files[i].capitalize()} PM10 predictions' for i in range(len(files))]
    df_yearly = df.groupby(la).mean()
    df_yearly = df_yearly[lb + lc].reset_index()
    sns.set_style('darkgrid')
    sns.set(rc={'figure.figsize':(14,8)})

    ex = sns.lineplot(data=df_yearly, x ='YM', y = 'Crniche PM10 actuals', label = 'Crniche PM10 actual values')
    mx = sns.lineplot(data=df_yearly, x ='YM', y = 'Crniche PM10 predictions', label = 'Crniche PM10 actual values')
    
    plt.legend(bbox_to_anchor=(1, 1))
    plt.ylabel('PM10 (µg/m3)')
    plt.xlabel('Year')
    plt.legend(loc="upper left")
    plt.show()
    


def plot_predictions_bardovci(model, X, y, y_df_test, start = 0, end = 100):
    predictions = model.predict(X)
    y_df_test = y_df_test[1:]
    
    list_Year = [str(i).split(" ")[0][0:4] for i in list(y_df_test.index)]
    list_YM = [str(i).split(" ")[0][:-3] for i in  list(y_df_test.index)]
    
    fields = ['sensor_id', 'lat', 'log']
    df = pd.DataFrame()
    for elem in files:
        for field in fields:
            df[f'{elem}_{field}'] = y_df_test[f'{elem}_{field}']
    
    for i in range(len(files)):
        df[f'{files[i].capitalize()} PM10 actuals'] = y[:, i]
        df[f'{files[i].capitalize()} PM10 predictions'] = predictions[:, i]

    df['Year'] = list_Year
    df['YM'] = list_YM
    
    la = [f'{elem}_{field}' for elem in files for field in fields]
    la.append('Year')
    la.append('YM')
    
    
    
    lb = [f'{files[i].capitalize()} PM10 actuals' for i in range(len(files))]
    lc = [f'{files[i].capitalize()} PM10 predictions' for i in range(len(files))]
    df_yearly = df.groupby(la).mean()
    df_yearly = df_yearly[lb + lc].reset_index()
    sns.set_style('darkgrid')
    sns.set(rc={'figure.figsize':(14,8)})

    fx = sns.lineplot(data=df_yearly, x ='YM', y = 'Bardovci PM10 actuals', label = 'Bardovci PM10 actual values')
    nx = sns.lineplot(data=df_yearly, x ='YM', y = 'Bardovci PM10 predictions', label = 'Bardovci PM10 actual values')


    plt.legend(bbox_to_anchor=(1, 1))
    plt.ylabel('PM10 (µg/m3)')
    plt.xlabel('Year')
    plt.legend(loc="upper left")
    plt.show()
    
    
def plot_predictions(model, X, y, y_df_test, start = 0, end = 100):
    predictions = model.predict(X)
    y_df_test = y_df_test[1:]
    
    list_Year = [str(i).split(" ")[0][0:4] for i in list(y_df_test.index)]
    list_YM = [str(i).split(" ")[0][:-3] for i in  list(y_df_test.index)]
    
    fields = ['sensor_id', 'lat', 'log']
    df = pd.DataFrame()
    for elem in files:
        for field in fields:
            df[f'{elem}_{field}'] = y_df_test[f'{elem}_{field}']
    
    for i in range(len(files)):
        df[f'{files[i].capitalize()} PM10 actuals'] = y[:, i]
        df[f'{files[i].capitalize()} PM10 predictions'] = predictions[:, i]

    df['Year'] = list_Year
    df['YM'] = list_YM
    
    la = [f'{elem}_{field}' for elem in files for field in fields]
    la.append('Year')
    la.append('YM')
    
    
    
    lb = [f'{files[i].capitalize()} PM10 actuals' for i in range(len(files))]
    lc = [f'{files[i].capitalize()} PM10 predictions' for i in range(len(files))]
    df_yearly = df.groupby(la).mean()
    df_yearly = df_yearly[lb + lc].reset_index()
    sns.set_style('darkgrid')
    sns.set(rc={'figure.figsize':(14,8)})

    ax = sns.lineplot(data=df_yearly, x ='YM', y = 'Zhelezara PM10 actuals', label = 'Zhelezara PM10 actual values')
    gx = sns.lineplot(data=df_yearly, x ='YM', y = 'Zhelezara PM10 predictions', label = 'Zhelezara PM10 predicted values')
    
    bx = sns.lineplot(data=df_yearly, x ='YM', y = '11_oktomvri PM10 actuals', label = '11 Oktomvri PM10 actual values')
    hx = sns.lineplot(data=df_yearly, x ='YM', y = '11_oktomvri PM10 predictions', label = '11 Oktomvri PM10 actual values')
    
    cx = sns.lineplot(data=df_yearly, x ='YM', y = 'Sopishte PM10 actuals', label = 'Sopishte PM10 actual values')
    jx = sns.lineplot(data=df_yearly, x ='YM', y = 'Sopishte PM10 predictions', label = 'Sopishte PM10 actual values')
    
    dx = sns.lineplot(data=df_yearly, x ='YM', y = 'Gjorche_stanica PM10 actuals', label = 'Gjorche_stanica PM10 actual values')
    kx = sns.lineplot(data=df_yearly, x ='YM', y = 'Gjorche_stanica PM10 predictions', label = 'Gjorche_stanica PM10 actual values')
    
    ex = sns.lineplot(data=df_yearly, x ='YM', y = 'Crniche PM10 actuals', label = 'Crniche PM10 actual values')
    mx = sns.lineplot(data=df_yearly, x ='YM', y = 'Crniche PM10 predictions', label = 'Crniche PM10 actual values')
    
    fx = sns.lineplot(data=df_yearly, x ='YM', y = 'Bardovci PM10 actuals', label = 'Bardovci PM10 actual values')
    nx = sns.lineplot(data=df_yearly, x ='YM', y = 'Bardovci PM10 predictions', label = 'Bardovci PM10 actual values')


    plt.legend(bbox_to_anchor=(1, 1))
    plt.ylabel('PM10 (µg/m3)')
    plt.xlabel('Year')
    plt.legend(loc="upper left")
    plt.show()
    

def move_to_first_column(name, df):
    first_column = df.pop(name)
    df.insert(0, name, first_column)
    return df

def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    
    for i in range(len(df_as_np) - window_size):
        row = [r for r in df_as_np[i:i+window_size]]
        X.append(row)
        label = [df_as_np[i+window_size][0], df_as_np[i+window_size][1], df_as_np[i+window_size][2], df_as_np[i+window_size][3], df_as_np[i+window_size][4], df_as_np[i+window_size][5]]
        y.append(label)
    return np.array(X), np.array(y)

def preprocess_output(y, X):
    for i in range(6):
        p_training_mean = np.mean(X[:, :, i])
        p_training_std = np.std(X[:, :, i])
        y[:, i] = np.abs((y[:, i] - p_training_mean) / p_training_std)
    
    return y

# %%
files = ['sopishte', 'bardovci', 'crniche', 'gjorche_stanica', '11_oktomvri', 'zhelezara']

# %%
folder_path = 'fixed-time-dataset'

_11_oktomvri = '11_oktomvri.csv'
zhelezara = 'zhelezara.csv'
sopishte = 'sopishte.csv'
bardovci = 'bardovci.csv'
crniche = 'crniche.csv'
gjorche_stanica = 'gjorche_stanica.csv'

window_size_1_hour = 4
window_size_6_hours = 24
window_size_12_hours = 48
window_size_24_hours = 96

window_size = window_size_12_hours

drop_columns = ['noise_dba']

# %%
df_sopishte = pd.read_csv(f'{folder_path}/{sopishte}', parse_dates=['date_time'], index_col='date_time').drop(columns = drop_columns)
df_bardovci = pd.read_csv(f'{folder_path}/{bardovci}', parse_dates=['date_time'], index_col='date_time').drop(columns = drop_columns)
df_crniche = pd.read_csv(f'{folder_path}/{crniche}', parse_dates=['date_time'], index_col='date_time').drop(columns = drop_columns)
df_gjorche_stanica = pd.read_csv(f'{folder_path}/{gjorche_stanica}', parse_dates=['date_time'], index_col='date_time').drop(columns = drop_columns)

df_11_oktomvri = pd.read_csv(f'{folder_path}/{_11_oktomvri}', parse_dates=['date_time'], index_col='date_time').drop(columns = drop_columns)
df_zhelezara = pd.read_csv(f'{folder_path}/{zhelezara}', parse_dates=['date_time'], index_col='date_time').drop(columns = drop_columns)

# %%
list_of_dfs = [df_sopishte, df_bardovci, df_crniche, df_gjorche_stanica, df_11_oktomvri, df_zhelezara]

# %%
for df in list_of_dfs:
    df['temperature'] = df['temperature'].interpolate(method='linear')
    df['humidity'] = df['humidity'].interpolate(method='linear')
    df['visibility'] = df['visibility'].interpolate(method='linear')
    df['pm25'] = df['pm25'].interpolate(method='linear')
    df['pm10'] = df['pm10'].interpolate(method='linear')

# %%
for i in range(len(list_of_dfs)):
    list_of_dfs[i].columns = [f'{files[i]}_{el}' for el in list(list_of_dfs[i].columns)]

# %%
merged_df = pd.concat(list_of_dfs, axis = 1)

# %%
merged_df.columns
# Out:
# Index(['sopishte_sensor_id', 'sopishte_lat', 'sopishte_log',
#        'sopishte_temperature', 'sopishte_noise', 'sopishte_pm10',
#        'sopishte_humidity', 'sopishte_pm25', 'sopishte_relative_humidity',
#        'sopishte_wind_speed',
#        ...
#        'zhelezara_wind_speed', 'zhelezara_sea_level_pressure',
#        'zhelezara_solar_elevation_angle', 'zhelezara_solar_radiation',
#        'zhelezara_pressure', 'zhelezara_snow', 'zhelezara_uv',
#        'zhelezara_wind_direction', 'zhelezara_visibility', 'zhelezara_clouds'],
#       dtype='object', length=114)

# %%
for elem in files:
    pm10_mean = merged_df[f'{elem}_pm10'].mean()
    pm10_std = merged_df[f'{elem}_pm10'].std()

    merged_df = merged_df[(merged_df[f'{elem}_pm10'] > (pm10_mean - 3 * pm10_std)) & (merged_df[f'{elem}_pm10'] < (pm10_mean + 3 * pm10_std))] #outliers removal

# %%
for elem in files:
    merged_df = move_to_first_column(f'{elem}_pm10', merged_df)

# %%
y_df = merged_df.iloc[window_size:, :]
fields = ['sensor_id', 'lat', 'log']
drop_cols = [f'{elem}_{field}' for elem in files for field in fields]

merged_df.drop(columns = drop_cols, inplace = True)
merged_df = merged_df[1:]

# %%
scaler = MinMaxScaler()
merged_df[list(merged_df.columns)[6:]] = scaler.fit_transform(merged_df[list(merged_df.columns)[6:]])
merged_df.head()
# Out:
#                      zhelezara_pm10  11_oktomvri_pm10  gjorche_stanica_pm10  \
# date_time
# 2017-11-09 00:45:00            32.0              71.0                  25.0
# 2017-11-09 01:00:00            35.0              43.0                  23.0
# 2017-11-09 01:15:00            37.0              42.0                  23.0
# 2017-11-09 01:30:00            27.0              42.0                  23.0
# 2017-11-09 01:45:00            35.0              36.0                  20.0
#
#                      crniche_pm10  bardovci_pm10  sopishte_pm10  \
# date_time
# 2017-11-09 00:45:00          57.0           51.0           98.0
# 2017-11-09 01:00:00          45.0           42.0           98.0
# 2017-11-09 01:15:00          39.0           59.0           26.0
# 2017-11-09 01:30:00          56.0           53.0           33.0
# 2017-11-09 01:45:00          40.0           54.0           35.0
#
#                      sopishte_temperature  sopishte_noise  sopishte_humidity  \
# date_time
# 2017-11-09 00:45:00              0.339286        0.076389           0.837209
# 2017-11-09 01:00:00              0.339286        0.076389           0.837209
# 2017-11-09 01:15:00              0.339286        0.076389           0.837209
# 2017-11-09 01:30:00              0.339286        0.083333           0.825581
# 2017-11-09 01:45:00              0.339286        0.076389           0.825581
#
#                      sopishte_pm25  ...  zhelezara_wind_speed  \
# date_time                           ...
# 2017-11-09 00:45:00       0.557971  ...              0.114869
# 2017-11-09 01:00:00       0.557971  ...              0.114509
# 2017-11-09 01:15:00       0.181159  ...              0.111532
# 2017-11-09 01:30:00       0.188406  ...              0.108548
# 2017-11-09 01:45:00       0.202899  ...              0.105571
#
#                      zhelezara_sea_level_pressure  \
# date_time
# 2017-11-09 00:45:00                      0.595224
# 2017-11-09 01:00:00                      0.596863
# 2017-11-09 01:15:00                      0.598458
# 2017-11-09 01:30:00                      0.600020
# 2017-11-09 01:45:00                      0.601553
#
#                      zhelezara_solar_elevation_angle  \
# date_time
# 2017-11-09 00:45:00                         0.087241
# 2017-11-09 01:00:00                         0.099898
# 2017-11-09 01:15:00                         0.117131
# 2017-11-09 01:30:00                         0.134401
# 2017-11-09 01:45:00                         0.151634
#
#                      zhelezara_solar_radiation  zhelezara_pressure  \
# date_time
# 2017-11-09 00:45:00               3.617752e-18            0.866006
# 2017-11-09 01:00:00               3.617752e-18            0.866534
# 2017-11-09 01:15:00               3.617752e-18            0.867099
# 2017-11-09 01:30:00               3.617752e-18            0.867684
# 2017-11-09 01:45:00               3.617752e-18            0.868272
#
#                      zhelezara_snow  zhelezara_uv  zhelezara_wind_direction  \
# date_time
# 2017-11-09 00:45:00             0.0           0.0                  0.659968
# 2017-11-09 01:00:00             0.0           0.0                  0.661003
# 2017-11-09 01:15:00             0.0           0.0                  0.661405
# 2017-11-09 01:30:00             0.0           0.0                  0.661378
# 2017-11-09 01:45:00             0.0           0.0                  0.661125
#
#                      zhelezara_visibility  zhelezara_clouds
# date_time
# 2017-11-09 00:45:00              0.278472          0.744739
# 2017-11-09 01:00:00              0.253924          0.753793
# 2017-11-09 01:15:00              0.286319          0.752476
# 2017-11-09 01:30:00              0.318785          0.744099
# 2017-11-09 01:45:00              0.351181          0.732039
#
# [5 rows x 96 columns]

# %%
X, y = df_to_X_y(merged_df, window_size = window_size)
X.shape, y.shape
# Out:
# ((134851, 48, 96), (134851, 6))

# %%
y
# Out:
# array([[19., 19., 16., 35., 25., 19.],
#        [24., 18., 18., 32., 30., 18.],
#        [21., 17., 15., 38., 34., 26.],
#        ...,
#        [13., 17., 18., 25., 23., 40.],
#        [15., 17., 24., 26., 23., 32.],
#        [15., 20., 19., 25., 18., 36.]])

# %%
X_train, y_train = X[:round(len(X)*0.7)], y[:round(len(y)*0.7)] #70%
X_val, y_val = X[round(len(X)*0.7):round(len(X)*0.9)], y[round(len(y)*0.7):round(len(y)*0.9)]
X_test, y_test = X[round(len(X)*0.9):], y[round(len(y)*0.9):]

X_train.shape, X_val.shape, X_test.shape, y_train.shape, y_val.shape, y_test.shape
# Out:
# ((94396, 48, 96),
#  (26970, 48, 96),
#  (13485, 48, 96),
#  (94396, 6),
#  (26970, 6),
#  (13485, 6))

# %%
y_test_df = y_df.iloc[round(len(X) * 0.9):, :]

# %%
preprocess_output(y_train, X)
preprocess_output(y_val, X)
preprocess_output(y_test, X)
# Out:
# array([[0.7587931 , 0.01998173, 0.33956894, 0.02781707, 0.78641098,
#         0.26022861],
#        [0.92968824, 0.04813349, 0.22031578, 0.02781707, 0.57685861,
#         0.26022861],
#        [0.84424067, 0.01407588, 0.18056472, 0.02781707, 0.6292467 ,
#         0.26022861],
#        ...,
#        [0.0956826 , 0.28653675, 0.17719477, 0.19532442, 0.0529777 ,
#         0.17374109],
#        [0.07521254, 0.28653675, 0.06131156, 0.23995272, 0.0529777 ,
#         0.21200975],
#        [0.07521254, 0.18436393, 0.13744371, 0.19532442, 0.20896276,
#         0.01913433]])

# %%
y_test_df.head()
# Out:
#                      zhelezara_pm10  11_oktomvri_pm10  gjorche_stanica_pm10  \
# date_time
# 2021-09-29 04:00:00            25.0              25.0                  30.0
# 2021-09-29 04:15:00            23.0              26.0                  31.0
# 2021-09-29 04:30:00            25.0              24.0                  28.0
# 2021-09-29 04:45:00            24.0              25.0                  27.0
# 2021-09-29 05:00:00            23.0              26.0                  39.0
#
#                      crniche_pm10  bardovci_pm10  sopishte_pm10  \
# date_time
# 2021-09-29 04:00:00          20.0           37.0           31.0
# 2021-09-29 04:15:00          20.0           37.0           31.0
# 2021-09-29 04:30:00          20.0           33.0           31.0
# 2021-09-29 04:45:00          20.0           34.0           31.0
# 2021-09-29 05:00:00          20.0           34.0           31.0
#
#                                        sopishte_sensor_id  sopishte_lat  \
# date_time
# 2021-09-29 04:00:00  6380c7cc-df23-4512-ad10-f2b363000579     41.960416
# 2021-09-29 04:15:00  6380c7cc-df23-4512-ad10-f2b363000579     41.960416
# 2021-09-29 04:30:00  6380c7cc-df23-4512-ad10-f2b363000579     41.960416
# 2021-09-29 04:45:00  6380c7cc-df23-4512-ad10-f2b363000579     41.960416
# 2021-09-29 05:00:00  6380c7cc-df23-4512-ad10-f2b363000579     41.960416
#
#                      sopishte_log  sopishte_temperature  ...  \
# date_time                                                ...
# 2021-09-29 04:00:00      21.43482                  14.0  ...
# 2021-09-29 04:15:00      21.43482                  14.0  ...
# 2021-09-29 04:30:00      21.43482                  14.0  ...
# 2021-09-29 04:45:00      21.43482                  14.0  ...
# 2021-09-29 05:00:00      21.43482                  14.0  ...
#
#                      zhelezara_wind_speed  zhelezara_sea_level_pressure  \
# date_time
# 2021-09-29 04:00:00                   1.0                   1019.972155
# 2021-09-29 04:15:00                   1.0                   1019.981105
# 2021-09-29 04:30:00                   1.0                   1019.988781
# 2021-09-29 04:45:00                   1.0                   1019.995724
# 2021-09-29 05:00:00                   1.0                   1020.002450
#
#                      zhelezara_solar_elevation_angle  \
# date_time
# 2021-09-29 04:00:00                       -27.287467
# 2021-09-29 04:15:00                       -24.547733
# 2021-09-29 04:30:00                       -21.808000
# 2021-09-29 04:45:00                       -19.065333
# 2021-09-29 05:00:00                       -16.281342
#
#                      zhelezara_solar_radiation  zhelezara_pressure  \
# date_time
# 2021-09-29 04:00:00                        0.0          984.319962
# 2021-09-29 04:15:00                        0.0          984.271062
# 2021-09-29 04:30:00                        0.0          984.227367
# 2021-09-29 04:45:00                        0.0          984.201443
# 2021-09-29 05:00:00                        0.0          984.205736
#
#                      zhelezara_snow  zhelezara_uv  zhelezara_wind_direction  \
# date_time
# 2021-09-29 04:00:00             0.0           0.0                194.661890
# 2021-09-29 04:15:00             0.0           0.0                193.188908
# 2021-09-29 04:30:00             0.0           0.0                191.862586
# 2021-09-29 04:45:00             0.0           0.0                190.679133
# 2021-09-29 05:00:00             0.0           0.0                189.636745
#
#                      zhelezara_visibility  zhelezara_clouds
# date_time
# 2021-09-29 04:00:00              4.000000         87.776421
# 2021-09-29 04:15:00              4.000000         91.597282
# 2021-09-29 04:30:00              4.000000         95.378535
# 2021-09-29 04:45:00              4.000000         98.555543
# 2021-09-29 05:00:00              3.905833        100.561708
#
# [5 rows x 114 columns]

# %%
input_size = (window_size, 96)
output_size = 6

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(LSTM(34, return_sequences=True))
model.add(LSTM(64))
model.add(Dense(8, 'relu'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 48, 34)            17816
#
#  lstm_3 (LSTM)               (None, 64)                25344
#
#  dense_4 (Dense)             (None, 8)                 520
#
#  dense_5 (Dense)             (None, 6)                 54
#
# =================================================================
# Total params: 43,734
# Trainable params: 43,734
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2950/2950 [==============================] - 114s 38ms/step - loss: 0.3353 - root_mean_squared_error: 0.5791 - val_loss: 0.2413 - val_root_mean_squared_error: 0.4912
# Epoch 2/10
# 2950/2950 [==============================] - 111s 38ms/step - loss: 0.1849 - root_mean_squared_error: 0.4299 - val_loss: 0.1836 - val_root_mean_squared_error: 0.4285
# Epoch 3/10
# 2950/2950 [==============================] - 134s 45ms/step - loss: 0.1467 - root_mean_squared_error: 0.3830 - val_loss: 0.1581 - val_root_mean_squared_error: 0.3976
# Epoch 4/10
# 2950/2950 [==============================] - 106s 36ms/step - loss: 0.1323 - root_mean_squared_error: 0.3637 - val_loss: 0.1455 - val_root_mean_squared_error: 0.3814
# Epoch 5/10
# 2950/2950 [==============================] - 177s 60ms/step - loss: 0.1251 - root_mean_squared_error: 0.3537 - val_loss: 0.1401 - val_root_mean_squared_error: 0.3743
# Epoch 6/10
# 2950/2950 [==============================] - 143s 48ms/step - loss: 0.1209 - root_mean_squared_error: 0.3476 - val_loss: 0.1353 - val_root_mean_squared_error: 0.3678
# Epoch 7/10
# 2950/2950 [==============================] - 136s 46ms/step - loss: 0.1180 - root_mean_squared_error: 0.3436 - val_loss: 0.1324 - val_root_mean_squared_error: 0.3638
# Epoch 8/10
# 2950/2950 [==============================] - 143s 49ms/step - loss: 0.1161 - root_mean_squared_error: 0.3407 - val_loss: 0.1314 - val_root_mean_squared_error: 0.3624
# Epoch 9/10
# 2950/2950 [==============================] - 130s 44ms/step - loss: 0.1145 - root_mean_squared_error: 0.3384 - val_loss: 0.1298 - val_root_mean_squared_error: 0.3603
# Epoch 10/10
# 2950/2950 [==============================] - 136s 46ms/step - loss: 0.1133 - root_mean_squared_error: 0.3366 - val_loss: 0.1277 - val_root_mean_squared_error: 0.3574
# 422/422 [==============================] - 7s 13ms/step

# %%
plt.figure(figsize=(20, 20))

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# 422/422 [==============================] - 5s 12ms/step

# %%
plt.figure(figsize=(20, 20))

plot_predictions_zhelezara(model, X_test, y_test, y_test_df)
# Out:
# 422/422 [==============================] - 5s 11ms/step

# %%
plt.figure(figsize=(20, 20))

plot_predictions_11_oktomvri(model, X_test, y_test, y_test_df)
# Out:
# 422/422 [==============================] - 5s 11ms/step

# %%
plt.figure(figsize=(20, 20))

plot_predictions_sopishte(model, X_test, y_test, y_test_df)
# Out:
# 422/422 [==============================] - 5s 12ms/step

# %%
plt.figure(figsize=(20, 20))

plot_predictions_gjorche_stanica(model, X_test, y_test, y_test_df)
# Out:
# 422/422 [==============================] - 5s 11ms/step

# %%
plt.figure(figsize=(20, 20))

plot_predictions_crniche(model, X_test, y_test, y_test_df)
# Out:
# 422/422 [==============================] - 5s 13ms/step

# %%
plt.figure(figsize=(20, 20))

plot_predictions_bardovci(model, X_test, y_test, y_test_df)
# Out:
# 422/422 [==============================] - 6s 13ms/step

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(LSTM(34, return_sequences=True))
model.add(LSTM(64))
model.add(Dense(8, 'selu'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 48, 34)            17816
#
#  lstm_5 (LSTM)               (None, 64)                25344
#
#  dense_6 (Dense)             (None, 8)                 520
#
#  dense_7 (Dense)             (None, 6)                 54
#
# =================================================================
# Total params: 43,734
# Trainable params: 43,734
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2950/2950 [==============================] - 158s 52ms/step - loss: 0.2911 - root_mean_squared_error: 0.5396 - val_loss: 0.2051 - val_root_mean_squared_error: 0.4529
# Epoch 2/10
# 2950/2950 [==============================] - 167s 57ms/step - loss: 0.1565 - root_mean_squared_error: 0.3956 - val_loss: 0.1641 - val_root_mean_squared_error: 0.4052
# Epoch 3/10
# 2950/2950 [==============================] - 136s 46ms/step - loss: 0.1366 - root_mean_squared_error: 0.3696 - val_loss: 0.1492 - val_root_mean_squared_error: 0.3863
# Epoch 4/10
# 2950/2950 [==============================] - 144s 49ms/step - loss: 0.1276 - root_mean_squared_error: 0.3572 - val_loss: 0.1450 - val_root_mean_squared_error: 0.3808
# Epoch 5/10
# 2950/2950 [==============================] - 158s 53ms/step - loss: 0.1221 - root_mean_squared_error: 0.3495 - val_loss: 0.1376 - val_root_mean_squared_error: 0.3709
# Epoch 6/10
# 2950/2950 [==============================] - 120s 41ms/step - loss: 0.1188 - root_mean_squared_error: 0.3447 - val_loss: 0.1325 - val_root_mean_squared_error: 0.3640
# Epoch 7/10
# 2950/2950 [==============================] - 122s 41ms/step - loss: 0.1164 - root_mean_squared_error: 0.3412 - val_loss: 0.1307 - val_root_mean_squared_error: 0.3616
# Epoch 8/10
# 2950/2950 [==============================] - 114s 39ms/step - loss: 0.1146 - root_mean_squared_error: 0.3385 - val_loss: 0.1284 - val_root_mean_squared_error: 0.3584
# Epoch 9/10
# 2950/2950 [==============================] - 115s 39ms/step - loss: 0.1132 - root_mean_squared_error: 0.3365 - val_loss: 0.1267 - val_root_mean_squared_error: 0.3559
# Epoch 10/10
# 2950/2950 [==============================] - 128s 43ms/step - loss: 0.1122 - root_mean_squared_error: 0.3350 - val_loss: 0.1265 - val_root_mean_squared_error: 0.3557
# 422/422 [==============================] - 7s 16ms/step

# %%
plt.figure(figsize=(20, 20))

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# 422/422 [==============================] - 5s 12ms/step

# %%
plt.figure(figsize=(20, 20))

plot_predictions_zhelezara(model, X_test, y_test, y_test_df)
# Out:
# 422/422 [==============================] - 5s 11ms/step

# %%
plt.figure(figsize=(20, 20))

plot_predictions_11_oktomvri(model, X_test, y_test, y_test_df)
# Out:
# 422/422 [==============================] - 5s 11ms/step

# %%
plt.figure(figsize=(20, 20))

plot_predictions_sopishte(model, X_test, y_test, y_test_df)
# Out:
# 422/422 [==============================] - 5s 13ms/step

# %%
plt.figure(figsize=(20, 20))

plot_predictions_gjorche_stanica(model, X_test, y_test, y_test_df)
# Out:
# 422/422 [==============================] - 6s 13ms/step

# %%
plt.figure(figsize=(20, 20))

plot_predictions_crniche(model, X_test, y_test, y_test_df)
# Out:
# 422/422 [==============================] - 6s 14ms/step

# %%
plt.figure(figsize=(20, 20))

plot_predictions_bardovci(model, X_test, y_test, y_test_df)
# Out:
# 422/422 [==============================] - 5s 12ms/step

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(GRU(64))
model.add(Dense(8, 'selu'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 64)                31104
#
#  dense_8 (Dense)             (None, 8)                 520
#
#  dense_9 (Dense)             (None, 6)                 54
#
# =================================================================
# Total params: 31,678
# Trainable params: 31,678
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2950/2950 [==============================] - 67s 22ms/step - loss: 0.3154 - root_mean_squared_error: 0.5616 - val_loss: 0.2478 - val_root_mean_squared_error: 0.4978
# Epoch 2/10
# 2950/2950 [==============================] - 60s 20ms/step - loss: 0.1910 - root_mean_squared_error: 0.4371 - val_loss: 0.1943 - val_root_mean_squared_error: 0.4408
# Epoch 3/10
# 2950/2950 [==============================] - 68s 23ms/step - loss: 0.1585 - root_mean_squared_error: 0.3982 - val_loss: 0.1704 - val_root_mean_squared_error: 0.4128
# Epoch 4/10
# 2950/2950 [==============================] - 59s 20ms/step - loss: 0.1439 - root_mean_squared_error: 0.3793 - val_loss: 0.1594 - val_root_mean_squared_error: 0.3993
# Epoch 5/10
# 2950/2950 [==============================] - 62s 21ms/step - loss: 0.1358 - root_mean_squared_error: 0.3686 - val_loss: 0.1524 - val_root_mean_squared_error: 0.3904
# Epoch 6/10
# 2950/2950 [==============================] - 67s 23ms/step - loss: 0.1308 - root_mean_squared_error: 0.3616 - val_loss: 0.1465 - val_root_mean_squared_error: 0.3827
# Epoch 7/10
# 2950/2950 [==============================] - 66s 22ms/step - loss: 0.1269 - root_mean_squared_error: 0.3562 - val_loss: 0.1424 - val_root_mean_squared_error: 0.3773
# Epoch 8/10
# 2950/2950 [==============================] - 68s 23ms/step - loss: 0.1238 - root_mean_squared_error: 0.3518 - val_loss: 0.1395 - val_root_mean_squared_error: 0.3735
# Epoch 9/10
# 2950/2950 [==============================] - 68s 23ms/step - loss: 0.1215 - root_mean_squared_error: 0.3485 - val_loss: 0.1365 - val_root_mean_squared_error: 0.3694
# Epoch 10/10
# 2950/2950 [==============================] - 102s 35ms/step - loss: 0.1196 - root_mean_squared_error: 0.3458 - val_loss: 0.1347 - val_root_mean_squared_error: 0.3670
# 422/422 [==============================] - 3s 6ms/step

# %%
plt.figure(figsize=(20, 20))

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# 422/422 [==============================] - 3s 7ms/step

# %%
plt.figure(figsize=(20, 20))

plot_predictions_zhelezara(model, X_test, y_test, y_test_df)
# Out:
# 422/422 [==============================] - 2s 6ms/step

# %%
plt.figure(figsize=(20, 20))

plot_predictions_11_oktomvri(model, X_test, y_test, y_test_df)
# Out:
# 422/422 [==============================] - 2s 5ms/step

# %%
plt.figure(figsize=(20, 20))

plot_predictions_sopishte(model, X_test, y_test, y_test_df)
# Out:
# 422/422 [==============================] - 3s 6ms/step

# %%
plt.figure(figsize=(20, 20))

plot_predictions_gjorche_stanica(model, X_test, y_test, y_test_df)
# Out:
# 422/422 [==============================] - 3s 7ms/step

# %%
plt.figure(figsize=(20, 20))

plot_predictions_crniche(model, X_test, y_test, y_test_df)
# Out:
# 422/422 [==============================] - 3s 6ms/step

# %%
plt.figure(figsize=(20, 20))

plot_predictions_bardovci(model, X_test, y_test, y_test_df)
# Out:
# 422/422 [==============================] - 3s 7ms/step
