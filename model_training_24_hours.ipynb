# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

import scipy.stats as st
from sklearn import ensemble, tree, linear_model

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError, MeanAbsolutePercentageError
from tensorflow.keras.optimizers import Adam

from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle

# %%
folder_path = 'fixed-time-dataset'
file_name = '11_oktomvri.csv'

drop_columns = ['noise_dba']

# %%
df = pd.read_csv(f'{folder_path}/{file_name}', parse_dates=['date_time'], index_col='date_time').drop(columns = drop_columns)

# %%
df.head()
# Out:
#                                                 sensor_id        lat  \
# date_time
# 2017-11-09 00:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  41.975155
# 2017-11-09 00:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  41.975155
# 2017-11-09 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  41.975155
# 2017-11-09 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  41.975155
# 2017-11-09 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  41.975155
#
#                            log  temperature  noise  pm10  humidity  pm25  \
# date_time
# 2017-11-09 00:30:00  21.456479         15.0     54    85      56.0    75
# 2017-11-09 00:45:00  21.456479         15.0     63    71      56.0    64
# 2017-11-09 01:00:00  21.456479          NaN     41    43      56.0    38
# 2017-11-09 01:15:00  21.456479         15.0     41    42      55.0    36
# 2017-11-09 01:30:00  21.456479         15.0     51    42      55.0    37
#
#                      relative_humidity  wind_speed  sea_level_pressure  \
# date_time
# 2017-11-09 00:30:00          88.534158    3.000000         1020.262889
# 2017-11-09 00:45:00          88.726425    3.000000         1020.339086
# 2017-11-09 01:00:00          89.066025    2.986333         1020.412789
# 2017-11-09 01:15:00          89.455443    2.908583         1020.484463
# 2017-11-09 01:30:00          89.798009    2.830833         1020.554562
#
#                      solar_elevation_angle  solar_radiation    pressure  snow  \
# date_time
# 2017-11-09 00:30:00             -60.352424              0.0  983.889298   0.0
# 2017-11-09 00:45:00             -58.482791              0.0  983.947339   0.0
# 2017-11-09 01:00:00             -56.399951              0.0  984.011669   0.0
# 2017-11-09 01:15:00             -54.133954              0.0  984.080274   0.0
# 2017-11-09 01:30:00             -51.713857              0.0  984.151176   0.0
#
#                       uv  wind_direction  visibility     clouds
# date_time
# 2017-11-09 00:30:00  0.0      268.620340    4.947778  78.943889
# 2017-11-09 00:45:00  0.0      269.554467    4.427778  83.363889
# 2017-11-09 01:00:00  0.0      270.063361    4.091111  86.817778
# 2017-11-09 01:15:00  0.0      270.253975    4.609444  85.781111
# 2017-11-09 01:30:00  0.0      270.231231    5.127778  84.744444

# %%
df['temperature'] = df['temperature'].interpolate(method='linear')
df['humidity'] = df['humidity'].interpolate(method='linear')
df['visibility'] = df['visibility'].interpolate(method='linear')
df['noise'] = df['noise'].interpolate(method='linear')
df['pm25'] = df['pm25'].interpolate(method='linear')

# %%
df.dropna()
# Out:
#                                                 sensor_id        lat  \
# date_time
# 2017-11-09 00:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  41.975155
# 2017-11-09 00:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  41.975155
# 2017-11-09 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  41.975155
# 2017-11-09 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  41.975155
# 2017-11-09 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  41.975155
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  41.975155
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  41.975155
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  41.975155
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  41.975155
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  41.975155
#
#                            log  temperature  noise  pm10  humidity  pm25  \
# date_time
# 2017-11-09 00:30:00  21.456479         15.0     54    85      56.0    75
# 2017-11-09 00:45:00  21.456479         15.0     63    71      56.0    64
# 2017-11-09 01:00:00  21.456479         15.0     41    43      56.0    38
# 2017-11-09 01:15:00  21.456479         15.0     41    42      55.0    36
# 2017-11-09 01:30:00  21.456479         15.0     51    42      55.0    37
# ...                        ...          ...    ...   ...       ...   ...
# 2022-03-02 22:45:00  21.456479         24.0     48    17      99.0    14
# 2022-03-02 23:00:00  21.456479         24.0     46    17      99.0    13
# 2022-03-02 23:15:00  21.456479         24.0     45    17      99.0    13
# 2022-03-02 23:30:00  21.456479         24.0     45    17      99.0    13
# 2022-03-02 23:45:00  21.456479         24.0     40    20      99.0    14
#
#                      relative_humidity  wind_speed  sea_level_pressure  \
# date_time
# 2017-11-09 00:30:00          88.534158    3.000000         1020.262889
# 2017-11-09 00:45:00          88.726425    3.000000         1020.339086
# 2017-11-09 01:00:00          89.066025    2.986333         1020.412789
# 2017-11-09 01:15:00          89.455443    2.908583         1020.484463
# 2017-11-09 01:30:00          89.798009    2.830833         1020.554562
# ...                                ...         ...                 ...
# 2022-03-02 22:45:00          57.761531    3.000000         1019.622560
# 2022-03-02 23:00:00          58.178665    3.000000         1019.584280
# 2022-03-02 23:15:00          58.549056    3.000000         1019.553725
# 2022-03-02 23:30:00          58.549056    3.000000         1019.553725
# 2022-03-02 23:45:00          58.830763    3.000000         1019.529156
#
#                      solar_elevation_angle  solar_radiation    pressure  snow  \
# date_time
# 2017-11-09 00:30:00             -60.352424              0.0  983.889298   0.0
# 2017-11-09 00:45:00             -58.482791              0.0  983.947339   0.0
# 2017-11-09 01:00:00             -56.399951              0.0  984.011669   0.0
# 2017-11-09 01:15:00             -54.133954              0.0  984.080274   0.0
# 2017-11-09 01:30:00             -51.713857              0.0  984.151176   0.0
# ...                                    ...              ...         ...   ...
# 2022-03-02 22:45:00             -52.704789              0.0  982.522899   0.0
# 2022-03-02 23:00:00             -53.676069              0.0  982.483911   0.0
# 2022-03-02 23:15:00             -54.341168              0.0  982.452439   0.0
# 2022-03-02 23:30:00             -54.341168              0.0  982.452439   0.0
# 2022-03-02 23:45:00             -54.687987              0.0  982.427447   0.0
#
#                       uv  wind_direction  visibility     clouds
# date_time
# 2017-11-09 00:30:00  0.0      268.620340    4.947778  78.943889
# 2017-11-09 00:45:00  0.0      269.554467    4.427778  83.363889
# 2017-11-09 01:00:00  0.0      270.063361    4.091111  86.817778
# 2017-11-09 01:15:00  0.0      270.253975    4.609444  85.781111
# 2017-11-09 01:30:00  0.0      270.231231    5.127778  84.744444
# ...                  ...             ...         ...        ...
# 2022-03-02 22:45:00  0.0      331.080483   10.000000  25.000000
# 2022-03-02 23:00:00  0.0      329.667205   10.000000  25.000000
# 2022-03-02 23:15:00  0.0      330.618992   10.000000  25.000000
# 2022-03-02 23:30:00  0.0      330.618992   10.000000  25.000000
# 2022-03-02 23:45:00  0.0      333.523186   10.000000  25.000000
#
# [151198 rows x 19 columns]

# %%
df.isnull().sum()
# Out:
# sensor_id                0
# lat                      0
# log                      0
# temperature              0
# noise                    0
# pm10                     0
# humidity                 0
# pm25                     0
# relative_humidity        0
# wind_speed               0
# sea_level_pressure       0
# solar_elevation_angle    0
# solar_radiation          0
# pressure                 0
# snow                     0
# uv                       0
# wind_direction           0
# visibility               0
# clouds                   0
# dtype: int64

# %%
pm10_mean = df['pm10'].mean()
pm10_std = df['pm10'].std()

df = df[(df['pm10'] > (pm10_mean - 3 * pm10_std)) & (df['pm10'] < (pm10_mean + 3 * pm10_std))] #outliers removal

# %%
def move_to_first_column(name, df):
    first_column = df.pop(name)
    df.insert(0, name, first_column)
    return df

def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    
    for i in range(len(df_as_np) - window_size):
        row = [r for r in df_as_np[i:i+window_size]]
        X.append(row)
        label = [df_as_np[i+window_size][0]]
        y.append(label)
    
    return np.array(X), np.array(y)

def plot_predictions(model, X, y, y_df_test, start = 0, end = 100):
    predictions = model.predict(X)
    p_preds = predictions[:, 0]
    p_actuals = y[:, 0]
    list_Year = [str(i).split(" ")[0][0:4] for i in list(y_df_test.index)]
    list_YM = [str(i).split(" ")[0][:-3] for i in  list(y_df_test.index)]
    df = pd.DataFrame(data = {'PM10 predictions': p_preds,
                                 'PM10 actuals': p_actuals,
                                'sensor_id': y_df_test['sensor_id'],
                              'log': y_df_test['log'],
                              'lat': y_df_test['lat']
                             })
    
    df['Year'] = list_Year
    df['YM'] = list_YM
    
    df_yearly = df.groupby(['sensor_id', 'lat', 'log', 'Year', 'YM']).mean()
    df_yearly = df_yearly[['PM10 predictions', 'PM10 actuals']].reset_index()
    sns.set_style('darkgrid')
    sns.set(rc={'figure.figsize':(14,8)})

    ax = sns.lineplot(data=df_yearly, x ='YM', y = 'PM10 predictions', label = 'Predicted values')
    bx = sns.lineplot(data=df_yearly, x ='YM', y = 'PM10 actuals', label = 'Actual values')


    plt.legend(bbox_to_anchor=(1, 1))
    plt.ylabel('PM10 (µg/m3)')
    plt.xlabel('Year')
    plt.legend(loc="upper left")
    plt.show()

    return df

def preprocess_output(y, X):
    p_training_mean = np.mean(X[:, :, 0])
    p_training_std = np.std(X[:, :, 0])
    y[:, 0] = np.abs((y[:, 0] - p_training_mean) / p_training_std)
    return y

# %%
df = move_to_first_column('pm10', df)

# %%
y_df = df.iloc[96:, :]
df.drop(columns = ['sensor_id', 'lat', 'log'], inplace = True)

# %%
scaler = MinMaxScaler()
df[list(df.columns)[1:]] = scaler.fit_transform(df[list(df.columns)[1:]])
df.head()
# Out:
#                      pm10  temperature     noise  humidity      pm25  \
# date_time
# 2017-11-09 00:30:00    85     0.469388  0.220238  0.516854  0.340909
# 2017-11-09 00:45:00    71     0.469388  0.273810  0.516854  0.290909
# 2017-11-09 01:00:00    43     0.469388  0.142857  0.516854  0.172727
# 2017-11-09 01:15:00    42     0.469388  0.142857  0.505618  0.163636
# 2017-11-09 01:30:00    42     0.469388  0.202381  0.505618  0.168182
#
#                      relative_humidity  wind_speed  sea_level_pressure  \
# date_time
# 2017-11-09 00:30:00           0.818695    0.113164            0.498549
# 2017-11-09 00:45:00           0.820693    0.113164            0.499968
# 2017-11-09 01:00:00           0.824221    0.112648            0.501341
# 2017-11-09 01:15:00           0.828266    0.109716            0.502677
# 2017-11-09 01:30:00           0.831825    0.106783            0.503983
#
#                      solar_elevation_angle  solar_radiation  pressure  snow  \
# date_time
# 2017-11-09 00:30:00               0.077042              0.0  0.812181   0.0
# 2017-11-09 00:45:00               0.090144              0.0  0.812629   0.0
# 2017-11-09 01:00:00               0.104740              0.0  0.813125   0.0
# 2017-11-09 01:15:00               0.120620              0.0  0.813655   0.0
# 2017-11-09 01:30:00               0.137579              0.0  0.814202   0.0
#
#                       uv  wind_direction  visibility    clouds
# date_time
# 2017-11-09 00:30:00  0.0        0.659931    0.309236  0.789439
# 2017-11-09 00:45:00  0.0        0.661751    0.276736  0.833639
# 2017-11-09 01:00:00  0.0        0.662742    0.255694  0.868178
# 2017-11-09 01:15:00  0.0        0.663113    0.288090  0.857811
# 2017-11-09 01:30:00  0.0        0.663069    0.320486  0.847444

# %%
X, y = df_to_X_y(df, window_size = 96) # 24 hours
X.shape, y.shape
# Out:
# ((147037, 96, 16), (147037, 1))

# %%
X_train, y_train = X[:round(len(X)*0.7)], y[:round(len(y)*0.7)] #70%
X_val, y_val = X[round(len(X)*0.7):round(len(X)*0.9)], y[round(len(y)*0.7):round(len(y)*0.9)]
X_test, y_test = X[round(len(X)*0.9):], y[round(len(y)*0.9):]

X_train.shape, X_val.shape, X_test.shape, y_train.shape, y_val.shape, y_test.shape
# Out:
# ((102926, 96, 16),
#  (29407, 96, 16),
#  (14704, 96, 16),
#  (102926, 1),
#  (29407, 1),
#  (14704, 1))

# %%
input_size = (96, 16)
output_size = 1

# %%
y_test_df = y_df.iloc[round(len(X) * 0.9):, :]

# %%
preprocess_output(y_train, X)
preprocess_output(y_val, X)
preprocess_output(y_test, X)
# Out:
# array([[0.33261006],
#        [0.33261006],
#        [0.31029996],
#        ...,
#        [0.37723024],
#        [0.37723024],
#        [0.31029996]])

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(LSTM(64))
model.add(Dense(8, 'relu'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[
    RootMeanSquaredError(),
    MeanAbsolutePercentageError()
])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                20736
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 21,265
# Trainable params: 21,265
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 172s 52ms/step - loss: 0.2059 - root_mean_squared_error: 0.4537 - mean_absolute_percentage_error: 116.1798 - val_loss: 0.0733 - val_root_mean_squared_error: 0.2706 - val_mean_absolute_percentage_error: 95.7565
# Epoch 2/10
# 3217/3217 [==============================] - 163s 51ms/step - loss: 0.0707 - root_mean_squared_error: 0.2658 - mean_absolute_percentage_error: 99.6873 - val_loss: 0.0696 - val_root_mean_squared_error: 0.2639 - val_mean_absolute_percentage_error: 83.1437
# Epoch 3/10
# 3217/3217 [==============================] - 156s 49ms/step - loss: 0.0691 - root_mean_squared_error: 0.2629 - mean_absolute_percentage_error: 95.7827 - val_loss: 0.0679 - val_root_mean_squared_error: 0.2605 - val_mean_absolute_percentage_error: 96.6456
# Epoch 4/10
# 3217/3217 [==============================] - 157s 49ms/step - loss: 0.0686 - root_mean_squared_error: 0.2619 - mean_absolute_percentage_error: 95.2364 - val_loss: 0.0675 - val_root_mean_squared_error: 0.2598 - val_mean_absolute_percentage_error: 99.4398
# Epoch 5/10
# 3217/3217 [==============================] - 171s 53ms/step - loss: 0.0679 - root_mean_squared_error: 0.2607 - mean_absolute_percentage_error: 94.3562 - val_loss: 0.0684 - val_root_mean_squared_error: 0.2616 - val_mean_absolute_percentage_error: 102.5318
# Epoch 6/10
# 3217/3217 [==============================] - 156s 48ms/step - loss: 0.0677 - root_mean_squared_error: 0.2603 - mean_absolute_percentage_error: 93.1347 - val_loss: 0.0691 - val_root_mean_squared_error: 0.2628 - val_mean_absolute_percentage_error: 90.9170
# Epoch 7/10
# 3217/3217 [==============================] - 159s 49ms/step - loss: 0.0675 - root_mean_squared_error: 0.2597 - mean_absolute_percentage_error: 93.6047 - val_loss: 0.0678 - val_root_mean_squared_error: 0.2604 - val_mean_absolute_percentage_error: 101.2202
# Epoch 8/10
# 3217/3217 [==============================] - 156s 49ms/step - loss: 0.0673 - root_mean_squared_error: 0.2594 - mean_absolute_percentage_error: 93.0253 - val_loss: 0.0669 - val_root_mean_squared_error: 0.2586 - val_mean_absolute_percentage_error: 109.9468
# Epoch 9/10
# 3217/3217 [==============================] - 161s 50ms/step - loss: 0.0669 - root_mean_squared_error: 0.2587 - mean_absolute_percentage_error: 92.9201 - val_loss: 0.0664 - val_root_mean_squared_error: 0.2577 - val_mean_absolute_percentage_error: 97.8667
# Epoch 10/10
# 3217/3217 [==============================] - 156s 49ms/step - loss: 0.0669 - root_mean_squared_error: 0.2586 - mean_absolute_percentage_error: 92.7363 - val_loss: 0.0692 - val_root_mean_squared_error: 0.2630 - val_mean_absolute_percentage_error: 77.8413
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.390155       0.33261
# 2021-09-27 01:15:00          0.355291       0.33261
# 2021-09-27 01:30:00          0.338989       0.31030
# 2021-09-27 01:45:00          0.312628       0.37723
# 2021-09-27 02:00:00          0.369504       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.381884       0.37723
# 2022-03-02 23:00:00          0.373486       0.37723
# 2022-03-02 23:15:00          0.372912       0.37723
# 2022-03-02 23:30:00          0.372723       0.37723
# 2022-03-02 23:45:00          0.372682       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(LSTM(64))
model.add(Dense(8, 'tanh'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[
    RootMeanSquaredError(),
    MeanAbsolutePercentageError()
])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 64)                20736
#
#  dense_2 (Dense)             (None, 8)                 520
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 21,265
# Trainable params: 21,265
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 169s 52ms/step - loss: 0.1718 - root_mean_squared_error: 0.4145 - mean_absolute_percentage_error: 118.7378 - val_loss: 0.0762 - val_root_mean_squared_error: 0.2760 - val_mean_absolute_percentage_error: 114.6857
# Epoch 2/10
# 3217/3217 [==============================] - 153s 48ms/step - loss: 0.0730 - root_mean_squared_error: 0.2701 - mean_absolute_percentage_error: 98.5308 - val_loss: 0.0704 - val_root_mean_squared_error: 0.2653 - val_mean_absolute_percentage_error: 87.5866
# Epoch 3/10
# 3217/3217 [==============================] - 155s 48ms/step - loss: 0.0702 - root_mean_squared_error: 0.2649 - mean_absolute_percentage_error: 96.7382 - val_loss: 0.0683 - val_root_mean_squared_error: 0.2613 - val_mean_absolute_percentage_error: 100.5923
# Epoch 4/10
# 3217/3217 [==============================] - 158s 49ms/step - loss: 0.0688 - root_mean_squared_error: 0.2623 - mean_absolute_percentage_error: 95.2161 - val_loss: 0.0675 - val_root_mean_squared_error: 0.2598 - val_mean_absolute_percentage_error: 107.5738
# Epoch 5/10
# 3217/3217 [==============================] - 155s 48ms/step - loss: 0.0683 - root_mean_squared_error: 0.2614 - mean_absolute_percentage_error: 95.1356 - val_loss: 0.0683 - val_root_mean_squared_error: 0.2614 - val_mean_absolute_percentage_error: 103.7719
# Epoch 6/10
# 3217/3217 [==============================] - 155s 48ms/step - loss: 0.0679 - root_mean_squared_error: 0.2606 - mean_absolute_percentage_error: 94.7326 - val_loss: 0.0663 - val_root_mean_squared_error: 0.2576 - val_mean_absolute_percentage_error: 97.5736
# Epoch 7/10
# 3217/3217 [==============================] - 157s 49ms/step - loss: 0.0677 - root_mean_squared_error: 0.2602 - mean_absolute_percentage_error: 94.4091 - val_loss: 0.0665 - val_root_mean_squared_error: 0.2580 - val_mean_absolute_percentage_error: 92.4243
# Epoch 8/10
# 3217/3217 [==============================] - 156s 49ms/step - loss: 0.0675 - root_mean_squared_error: 0.2597 - mean_absolute_percentage_error: 94.0654 - val_loss: 0.0661 - val_root_mean_squared_error: 0.2571 - val_mean_absolute_percentage_error: 84.7852
# Epoch 9/10
# 3217/3217 [==============================] - 155s 48ms/step - loss: 0.0676 - root_mean_squared_error: 0.2599 - mean_absolute_percentage_error: 93.8934 - val_loss: 0.0660 - val_root_mean_squared_error: 0.2570 - val_mean_absolute_percentage_error: 90.1836
# Epoch 10/10
# 3217/3217 [==============================] - 157s 49ms/step - loss: 0.0671 - root_mean_squared_error: 0.2590 - mean_absolute_percentage_error: 93.1483 - val_loss: 0.0657 - val_root_mean_squared_error: 0.2563 - val_mean_absolute_percentage_error: 89.9981
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.393923       0.33261
# 2021-09-27 01:15:00          0.351833       0.33261
# 2021-09-27 01:30:00          0.339400       0.31030
# 2021-09-27 01:45:00          0.322106       0.37723
# 2021-09-27 02:00:00          0.356985       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.386495       0.37723
# 2022-03-02 23:00:00          0.379547       0.37723
# 2022-03-02 23:15:00          0.377667       0.37723
# 2022-03-02 23:30:00          0.376334       0.37723
# 2022-03-02 23:45:00          0.375250       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(LSTM(64))
model.add(Dense(8, 'sigmoid'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[
    RootMeanSquaredError(),
    MeanAbsolutePercentageError()
])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 64)                20736
#
#  dense_4 (Dense)             (None, 8)                 520
#
#  dense_5 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 21,265
# Trainable params: 21,265
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 168s 51ms/step - loss: 0.2138 - root_mean_squared_error: 0.4624 - mean_absolute_percentage_error: 122.4373 - val_loss: 0.1032 - val_root_mean_squared_error: 0.3213 - val_mean_absolute_percentage_error: 104.0447
# Epoch 2/10
# 3217/3217 [==============================] - 160s 50ms/step - loss: 0.0867 - root_mean_squared_error: 0.2945 - mean_absolute_percentage_error: 102.1664 - val_loss: 0.0786 - val_root_mean_squared_error: 0.2804 - val_mean_absolute_percentage_error: 90.8828
# Epoch 3/10
# 3217/3217 [==============================] - 168s 52ms/step - loss: 0.0736 - root_mean_squared_error: 0.2714 - mean_absolute_percentage_error: 98.0325 - val_loss: 0.0706 - val_root_mean_squared_error: 0.2658 - val_mean_absolute_percentage_error: 95.0387
# Epoch 4/10
# 3217/3217 [==============================] - 216s 67ms/step - loss: 0.0701 - root_mean_squared_error: 0.2648 - mean_absolute_percentage_error: 96.6966 - val_loss: 0.0689 - val_root_mean_squared_error: 0.2626 - val_mean_absolute_percentage_error: 89.2205
# Epoch 5/10
# 3217/3217 [==============================] - 192s 60ms/step - loss: 0.0688 - root_mean_squared_error: 0.2624 - mean_absolute_percentage_error: 95.9099 - val_loss: 0.0683 - val_root_mean_squared_error: 0.2613 - val_mean_absolute_percentage_error: 88.0453
# Epoch 6/10
# 3217/3217 [==============================] - 189s 59ms/step - loss: 0.0683 - root_mean_squared_error: 0.2613 - mean_absolute_percentage_error: 95.4074 - val_loss: 0.0674 - val_root_mean_squared_error: 0.2596 - val_mean_absolute_percentage_error: 89.0715
# Epoch 7/10
# 3217/3217 [==============================] - 202s 63ms/step - loss: 0.0679 - root_mean_squared_error: 0.2606 - mean_absolute_percentage_error: 95.4468 - val_loss: 0.0677 - val_root_mean_squared_error: 0.2602 - val_mean_absolute_percentage_error: 82.5373
# Epoch 8/10
# 3217/3217 [==============================] - 201s 63ms/step - loss: 0.0676 - root_mean_squared_error: 0.2600 - mean_absolute_percentage_error: 94.0884 - val_loss: 0.0665 - val_root_mean_squared_error: 0.2579 - val_mean_absolute_percentage_error: 91.7505
# Epoch 9/10
# 3217/3217 [==============================] - 203s 63ms/step - loss: 0.0673 - root_mean_squared_error: 0.2595 - mean_absolute_percentage_error: 94.4967 - val_loss: 0.0689 - val_root_mean_squared_error: 0.2625 - val_mean_absolute_percentage_error: 84.8241
# Epoch 10/10
# 3217/3217 [==============================] - 197s 61ms/step - loss: 0.0669 - root_mean_squared_error: 0.2587 - mean_absolute_percentage_error: 93.9768 - val_loss: 0.0680 - val_root_mean_squared_error: 0.2607 - val_mean_absolute_percentage_error: 90.5044
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.382410       0.33261
# 2021-09-27 01:15:00          0.339033       0.33261
# 2021-09-27 01:30:00          0.327796       0.31030
# 2021-09-27 01:45:00          0.309753       0.37723
# 2021-09-27 02:00:00          0.348679       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.365744       0.37723
# 2022-03-02 23:00:00          0.359214       0.37723
# 2022-03-02 23:15:00          0.356433       0.37723
# 2022-03-02 23:30:00          0.355140       0.37723
# 2022-03-02 23:45:00          0.354505       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(LSTM(64))
model.add(Dense(8, 'selu'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[
    RootMeanSquaredError(),
    MeanAbsolutePercentageError()
])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 64)                20736
#
#  dense_6 (Dense)             (None, 8)                 520
#
#  dense_7 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 21,265
# Trainable params: 21,265
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 194s 59ms/step - loss: 0.1029 - root_mean_squared_error: 0.3207 - mean_absolute_percentage_error: 109.5749 - val_loss: 0.0711 - val_root_mean_squared_error: 0.2667 - val_mean_absolute_percentage_error: 99.1887
# Epoch 2/10
# 3217/3217 [==============================] - 178s 55ms/step - loss: 0.0701 - root_mean_squared_error: 0.2648 - mean_absolute_percentage_error: 99.3927 - val_loss: 0.0699 - val_root_mean_squared_error: 0.2643 - val_mean_absolute_percentage_error: 92.2313
# Epoch 3/10
# 3217/3217 [==============================] - 159s 50ms/step - loss: 0.0691 - root_mean_squared_error: 0.2629 - mean_absolute_percentage_error: 97.9126 - val_loss: 0.0677 - val_root_mean_squared_error: 0.2603 - val_mean_absolute_percentage_error: 95.0128
# Epoch 4/10
# 3217/3217 [==============================] - 162s 50ms/step - loss: 0.0685 - root_mean_squared_error: 0.2617 - mean_absolute_percentage_error: 96.4122 - val_loss: 0.0674 - val_root_mean_squared_error: 0.2597 - val_mean_absolute_percentage_error: 106.2761
# Epoch 5/10
# 3217/3217 [==============================] - 164s 51ms/step - loss: 0.0681 - root_mean_squared_error: 0.2610 - mean_absolute_percentage_error: 96.0852 - val_loss: 0.0676 - val_root_mean_squared_error: 0.2600 - val_mean_absolute_percentage_error: 82.5103
# Epoch 6/10
# 3217/3217 [==============================] - 161s 50ms/step - loss: 0.0679 - root_mean_squared_error: 0.2606 - mean_absolute_percentage_error: 95.4779 - val_loss: 0.0666 - val_root_mean_squared_error: 0.2581 - val_mean_absolute_percentage_error: 90.2806
# Epoch 7/10
# 3217/3217 [==============================] - 160s 50ms/step - loss: 0.0676 - root_mean_squared_error: 0.2600 - mean_absolute_percentage_error: 94.7174 - val_loss: 0.0665 - val_root_mean_squared_error: 0.2580 - val_mean_absolute_percentage_error: 87.7844
# Epoch 8/10
# 3217/3217 [==============================] - 160s 50ms/step - loss: 0.0676 - root_mean_squared_error: 0.2600 - mean_absolute_percentage_error: 94.8315 - val_loss: 0.0679 - val_root_mean_squared_error: 0.2606 - val_mean_absolute_percentage_error: 82.9870
# Epoch 9/10
# 3217/3217 [==============================] - 160s 50ms/step - loss: 0.0674 - root_mean_squared_error: 0.2595 - mean_absolute_percentage_error: 94.9235 - val_loss: 0.0668 - val_root_mean_squared_error: 0.2585 - val_mean_absolute_percentage_error: 82.4624
# Epoch 10/10
# 3217/3217 [==============================] - 159s 50ms/step - loss: 0.0672 - root_mean_squared_error: 0.2592 - mean_absolute_percentage_error: 94.7140 - val_loss: 0.0668 - val_root_mean_squared_error: 0.2584 - val_mean_absolute_percentage_error: 97.2649
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.364613       0.33261
# 2021-09-27 01:15:00          0.323983       0.33261
# 2021-09-27 01:30:00          0.315567       0.31030
# 2021-09-27 01:45:00          0.297186       0.37723
# 2021-09-27 02:00:00          0.338338       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.366047       0.37723
# 2022-03-02 23:00:00          0.354093       0.37723
# 2022-03-02 23:15:00          0.349527       0.37723
# 2022-03-02 23:30:00          0.347657       0.37723
# 2022-03-02 23:45:00          0.347101       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(LSTM(34, return_sequences=True))
model.add(LSTM(64))
model.add(Dense(8, 'relu'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 96, 34)            6936
#
#  lstm_5 (LSTM)               (None, 64)                25344
#
#  dense_8 (Dense)             (None, 8)                 520
#
#  dense_9 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 32,809
# Trainable params: 32,809
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 299s 91ms/step - loss: 0.1409 - root_mean_squared_error: 0.3754 - val_loss: 0.0791 - val_root_mean_squared_error: 0.2813
# Epoch 2/10
# 3217/3217 [==============================] - 294s 91ms/step - loss: 0.0753 - root_mean_squared_error: 0.2743 - val_loss: 0.0709 - val_root_mean_squared_error: 0.2664
# Epoch 3/10
# 3217/3217 [==============================] - 292s 91ms/step - loss: 0.0704 - root_mean_squared_error: 0.2654 - val_loss: 0.0682 - val_root_mean_squared_error: 0.2611
# Epoch 4/10
# 3217/3217 [==============================] - 290s 90ms/step - loss: 0.0686 - root_mean_squared_error: 0.2619 - val_loss: 0.0670 - val_root_mean_squared_error: 0.2589
# Epoch 5/10
# 3217/3217 [==============================] - 296s 92ms/step - loss: 0.0683 - root_mean_squared_error: 0.2613 - val_loss: 0.0672 - val_root_mean_squared_error: 0.2593
# Epoch 6/10
# 3217/3217 [==============================] - 293s 91ms/step - loss: 0.0677 - root_mean_squared_error: 0.2601 - val_loss: 0.0665 - val_root_mean_squared_error: 0.2579
# Epoch 7/10
# 3217/3217 [==============================] - 291s 90ms/step - loss: 0.0672 - root_mean_squared_error: 0.2592 - val_loss: 0.0725 - val_root_mean_squared_error: 0.2692
# Epoch 8/10
# 3217/3217 [==============================] - 292s 91ms/step - loss: 0.0671 - root_mean_squared_error: 0.2590 - val_loss: 0.0659 - val_root_mean_squared_error: 0.2567
# Epoch 9/10
# 3217/3217 [==============================] - 293s 91ms/step - loss: 0.0668 - root_mean_squared_error: 0.2585 - val_loss: 0.0660 - val_root_mean_squared_error: 0.2569
# Epoch 10/10
# 3217/3217 [==============================] - 290s 90ms/step - loss: 0.0668 - root_mean_squared_error: 0.2585 - val_loss: 0.0655 - val_root_mean_squared_error: 0.2560
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.382824       0.33261
# 2021-09-27 01:15:00          0.343035       0.33261
# 2021-09-27 01:30:00          0.331049       0.31030
# 2021-09-27 01:45:00          0.310714       0.37723
# 2021-09-27 02:00:00          0.344489       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.387474       0.37723
# 2022-03-02 23:00:00          0.377605       0.37723
# 2022-03-02 23:15:00          0.370051       0.37723
# 2022-03-02 23:30:00          0.365273       0.37723
# 2022-03-02 23:45:00          0.362357       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(LSTM(34, return_sequences=True))
model.add(LSTM(64))
model.add(Dense(8, 'tanh'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 96, 34)            6936
#
#  lstm_7 (LSTM)               (None, 64)                25344
#
#  dense_10 (Dense)            (None, 8)                 520
#
#  dense_11 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 32,809
# Trainable params: 32,809
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 302s 93ms/step - loss: 0.1209 - root_mean_squared_error: 0.3477 - val_loss: 0.0763 - val_root_mean_squared_error: 0.2761
# Epoch 2/10
# 3217/3217 [==============================] - 296s 92ms/step - loss: 0.0737 - root_mean_squared_error: 0.2714 - val_loss: 0.0694 - val_root_mean_squared_error: 0.2635
# Epoch 3/10
# 3217/3217 [==============================] - 296s 92ms/step - loss: 0.0705 - root_mean_squared_error: 0.2655 - val_loss: 0.0675 - val_root_mean_squared_error: 0.2599
# Epoch 4/10
# 3217/3217 [==============================] - 295s 92ms/step - loss: 0.0688 - root_mean_squared_error: 0.2623 - val_loss: 0.0684 - val_root_mean_squared_error: 0.2614
# Epoch 5/10
# 3217/3217 [==============================] - 295s 92ms/step - loss: 0.0683 - root_mean_squared_error: 0.2614 - val_loss: 0.0678 - val_root_mean_squared_error: 0.2604
# Epoch 6/10
# 3217/3217 [==============================] - 294s 91ms/step - loss: 0.0680 - root_mean_squared_error: 0.2609 - val_loss: 0.0686 - val_root_mean_squared_error: 0.2619
# Epoch 7/10
# 3217/3217 [==============================] - 296s 92ms/step - loss: 0.0676 - root_mean_squared_error: 0.2601 - val_loss: 0.0677 - val_root_mean_squared_error: 0.2602
# Epoch 8/10
# 3217/3217 [==============================] - 298s 92ms/step - loss: 0.0673 - root_mean_squared_error: 0.2594 - val_loss: 0.0661 - val_root_mean_squared_error: 0.2571
# Epoch 9/10
# 3217/3217 [==============================] - 297s 92ms/step - loss: 0.0672 - root_mean_squared_error: 0.2592 - val_loss: 0.0655 - val_root_mean_squared_error: 0.2559
# Epoch 10/10
# 3217/3217 [==============================] - 297s 92ms/step - loss: 0.0669 - root_mean_squared_error: 0.2586 - val_loss: 0.0669 - val_root_mean_squared_error: 0.2587
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.400417       0.33261
# 2021-09-27 01:15:00          0.354858       0.33261
# 2021-09-27 01:30:00          0.347457       0.31030
# 2021-09-27 01:45:00          0.328934       0.37723
# 2021-09-27 02:00:00          0.372895       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.392302       0.37723
# 2022-03-02 23:00:00          0.387134       0.37723
# 2022-03-02 23:15:00          0.383895       0.37723
# 2022-03-02 23:30:00          0.381654       0.37723
# 2022-03-02 23:45:00          0.380580       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(LSTM(34, return_sequences=True))
model.add(LSTM(64))
model.add(Dense(8, 'sigmoid'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 96, 34)            6936
#
#  lstm_9 (LSTM)               (None, 64)                25344
#
#  dense_12 (Dense)            (None, 8)                 520
#
#  dense_13 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 32,809
# Trainable params: 32,809
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 307s 94ms/step - loss: 0.1431 - root_mean_squared_error: 0.3783 - val_loss: 0.0922 - val_root_mean_squared_error: 0.3036
# Epoch 2/10
# 3217/3217 [==============================] - 302s 94ms/step - loss: 0.0798 - root_mean_squared_error: 0.2825 - val_loss: 0.0722 - val_root_mean_squared_error: 0.2687
# Epoch 3/10
# 3217/3217 [==============================] - 298s 93ms/step - loss: 0.0717 - root_mean_squared_error: 0.2677 - val_loss: 0.0720 - val_root_mean_squared_error: 0.2683
# Epoch 4/10
# 3217/3217 [==============================] - 297s 92ms/step - loss: 0.0694 - root_mean_squared_error: 0.2634 - val_loss: 0.0674 - val_root_mean_squared_error: 0.2595
# Epoch 5/10
# 3217/3217 [==============================] - 299s 93ms/step - loss: 0.0684 - root_mean_squared_error: 0.2616 - val_loss: 0.0688 - val_root_mean_squared_error: 0.2624
# Epoch 6/10
# 3217/3217 [==============================] - 302s 94ms/step - loss: 0.0676 - root_mean_squared_error: 0.2600 - val_loss: 0.0684 - val_root_mean_squared_error: 0.2615
# Epoch 7/10
# 3217/3217 [==============================] - 302s 94ms/step - loss: 0.0672 - root_mean_squared_error: 0.2593 - val_loss: 0.0688 - val_root_mean_squared_error: 0.2623
# Epoch 8/10
# 3217/3217 [==============================] - 302s 94ms/step - loss: 0.0670 - root_mean_squared_error: 0.2589 - val_loss: 0.0661 - val_root_mean_squared_error: 0.2571
# Epoch 9/10
# 3217/3217 [==============================] - 302s 94ms/step - loss: 0.0668 - root_mean_squared_error: 0.2584 - val_loss: 0.0691 - val_root_mean_squared_error: 0.2629
# Epoch 10/10
# 3217/3217 [==============================] - 301s 94ms/step - loss: 0.0666 - root_mean_squared_error: 0.2581 - val_loss: 0.0669 - val_root_mean_squared_error: 0.2586
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.411488       0.33261
# 2021-09-27 01:15:00          0.374998       0.33261
# 2021-09-27 01:30:00          0.362237       0.31030
# 2021-09-27 01:45:00          0.343125       0.37723
# 2021-09-27 02:00:00          0.376198       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.412530       0.37723
# 2022-03-02 23:00:00          0.403497       0.37723
# 2022-03-02 23:15:00          0.397811       0.37723
# 2022-03-02 23:30:00          0.394035       0.37723
# 2022-03-02 23:45:00          0.391609       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(LSTM(34, return_sequences=True))
model.add(LSTM(64))
model.add(Dense(8, 'selu'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (None, 96, 34)            6936
#
#  lstm_11 (LSTM)              (None, 64)                25344
#
#  dense_14 (Dense)            (None, 8)                 520
#
#  dense_15 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 32,809
# Trainable params: 32,809
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 305s 93ms/step - loss: 0.1157 - root_mean_squared_error: 0.3402 - val_loss: 0.0765 - val_root_mean_squared_error: 0.2766
# Epoch 2/10
# 3217/3217 [==============================] - 296s 92ms/step - loss: 0.0725 - root_mean_squared_error: 0.2692 - val_loss: 0.0730 - val_root_mean_squared_error: 0.2703
# Epoch 3/10
# 3217/3217 [==============================] - 294s 91ms/step - loss: 0.0701 - root_mean_squared_error: 0.2648 - val_loss: 0.0685 - val_root_mean_squared_error: 0.2618
# Epoch 4/10
# 3217/3217 [==============================] - 294s 91ms/step - loss: 0.0691 - root_mean_squared_error: 0.2629 - val_loss: 0.0675 - val_root_mean_squared_error: 0.2597
# Epoch 5/10
# 3217/3217 [==============================] - 295s 92ms/step - loss: 0.0686 - root_mean_squared_error: 0.2619 - val_loss: 0.0680 - val_root_mean_squared_error: 0.2608
# Epoch 6/10
# 3217/3217 [==============================] - 297s 92ms/step - loss: 0.0683 - root_mean_squared_error: 0.2614 - val_loss: 0.0664 - val_root_mean_squared_error: 0.2577
# Epoch 7/10
# 3217/3217 [==============================] - 302s 94ms/step - loss: 0.0679 - root_mean_squared_error: 0.2605 - val_loss: 0.0660 - val_root_mean_squared_error: 0.2569
# Epoch 8/10
# 3217/3217 [==============================] - 301s 93ms/step - loss: 0.0674 - root_mean_squared_error: 0.2597 - val_loss: 0.0689 - val_root_mean_squared_error: 0.2625
# Epoch 9/10
# 3217/3217 [==============================] - 298s 93ms/step - loss: 0.0673 - root_mean_squared_error: 0.2594 - val_loss: 0.0672 - val_root_mean_squared_error: 0.2593
# Epoch 10/10
# 3217/3217 [==============================] - 299s 93ms/step - loss: 0.0669 - root_mean_squared_error: 0.2587 - val_loss: 0.0663 - val_root_mean_squared_error: 0.2576
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.405835       0.33261
# 2021-09-27 01:15:00          0.362975       0.33261
# 2021-09-27 01:30:00          0.351967       0.31030
# 2021-09-27 01:45:00          0.332079       0.37723
# 2021-09-27 02:00:00          0.373068       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.408645       0.37723
# 2022-03-02 23:00:00          0.397800       0.37723
# 2022-03-02 23:15:00          0.390645       0.37723
# 2022-03-02 23:30:00          0.387048       0.37723
# 2022-03-02 23:45:00          0.385663       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(GRU(64))
model.add(Dense(8, 'relu'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 64)                15744
#
#  dense_16 (Dense)            (None, 8)                 520
#
#  dense_17 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 16,273
# Trainable params: 16,273
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 155s 48ms/step - loss: 0.1299 - root_mean_squared_error: 0.3604 - val_loss: 0.0726 - val_root_mean_squared_error: 0.2694
# Epoch 2/10
# 3217/3217 [==============================] - 152s 47ms/step - loss: 0.0695 - root_mean_squared_error: 0.2636 - val_loss: 0.0686 - val_root_mean_squared_error: 0.2620
# Epoch 3/10
# 3217/3217 [==============================] - 153s 48ms/step - loss: 0.0685 - root_mean_squared_error: 0.2618 - val_loss: 0.0693 - val_root_mean_squared_error: 0.2632
# Epoch 4/10
# 3217/3217 [==============================] - 153s 47ms/step - loss: 0.0680 - root_mean_squared_error: 0.2608 - val_loss: 0.0692 - val_root_mean_squared_error: 0.2630
# Epoch 5/10
# 3217/3217 [==============================] - 161s 50ms/step - loss: 0.0679 - root_mean_squared_error: 0.2605 - val_loss: 0.0669 - val_root_mean_squared_error: 0.2586
# Epoch 6/10
# 3217/3217 [==============================] - 156s 49ms/step - loss: 0.0675 - root_mean_squared_error: 0.2599 - val_loss: 0.0676 - val_root_mean_squared_error: 0.2601
# Epoch 7/10
# 3217/3217 [==============================] - 156s 49ms/step - loss: 0.0671 - root_mean_squared_error: 0.2591 - val_loss: 0.0680 - val_root_mean_squared_error: 0.2608
# Epoch 8/10
# 3217/3217 [==============================] - 156s 48ms/step - loss: 0.0671 - root_mean_squared_error: 0.2590 - val_loss: 0.0683 - val_root_mean_squared_error: 0.2614
# Epoch 9/10
# 3217/3217 [==============================] - 188s 58ms/step - loss: 0.0670 - root_mean_squared_error: 0.2588 - val_loss: 0.0656 - val_root_mean_squared_error: 0.2562
# Epoch 10/10
# 3217/3217 [==============================] - 184s 57ms/step - loss: 0.0666 - root_mean_squared_error: 0.2580 - val_loss: 0.0655 - val_root_mean_squared_error: 0.2560
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.372792       0.33261
# 2021-09-27 01:15:00          0.328422       0.33261
# 2021-09-27 01:30:00          0.315409       0.31030
# 2021-09-27 01:45:00          0.298477       0.37723
# 2021-09-27 02:00:00          0.335232       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.366280       0.37723
# 2022-03-02 23:00:00          0.353588       0.37723
# 2022-03-02 23:15:00          0.348590       0.37723
# 2022-03-02 23:30:00          0.346352       0.37723
# 2022-03-02 23:45:00          0.345136       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(GRU(64))
model.add(Dense(8, 'tanh'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 64)                15744
#
#  dense_18 (Dense)            (None, 8)                 520
#
#  dense_19 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 16,273
# Trainable params: 16,273
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 215s 66ms/step - loss: 0.1215 - root_mean_squared_error: 0.3485 - val_loss: 0.0710 - val_root_mean_squared_error: 0.2664
# Epoch 2/10
# 3217/3217 [==============================] - 226s 70ms/step - loss: 0.0702 - root_mean_squared_error: 0.2649 - val_loss: 0.0683 - val_root_mean_squared_error: 0.2614
# Epoch 3/10
# 3217/3217 [==============================] - 205s 64ms/step - loss: 0.0686 - root_mean_squared_error: 0.2619 - val_loss: 0.0669 - val_root_mean_squared_error: 0.2587
# Epoch 4/10
# 3217/3217 [==============================] - 213s 66ms/step - loss: 0.0681 - root_mean_squared_error: 0.2610 - val_loss: 0.0670 - val_root_mean_squared_error: 0.2589
# Epoch 5/10
# 3217/3217 [==============================] - 206s 64ms/step - loss: 0.0678 - root_mean_squared_error: 0.2605 - val_loss: 0.0669 - val_root_mean_squared_error: 0.2587
# Epoch 6/10
# 3217/3217 [==============================] - 224s 70ms/step - loss: 0.0676 - root_mean_squared_error: 0.2600 - val_loss: 0.0667 - val_root_mean_squared_error: 0.2583
# Epoch 7/10
# 3217/3217 [==============================] - 265s 82ms/step - loss: 0.0674 - root_mean_squared_error: 0.2596 - val_loss: 0.0665 - val_root_mean_squared_error: 0.2579
# Epoch 8/10
# 3217/3217 [==============================] - 225s 70ms/step - loss: 0.0672 - root_mean_squared_error: 0.2592 - val_loss: 0.0668 - val_root_mean_squared_error: 0.2585
# Epoch 9/10
# 3217/3217 [==============================] - 203s 63ms/step - loss: 0.0671 - root_mean_squared_error: 0.2590 - val_loss: 0.0660 - val_root_mean_squared_error: 0.2568
# Epoch 10/10
# 3217/3217 [==============================] - 171s 53ms/step - loss: 0.0669 - root_mean_squared_error: 0.2587 - val_loss: 0.0660 - val_root_mean_squared_error: 0.2569
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.424754       0.33261
# 2021-09-27 01:15:00          0.384795       0.33261
# 2021-09-27 01:30:00          0.374867       0.31030
# 2021-09-27 01:45:00          0.358758       0.37723
# 2021-09-27 02:00:00          0.395040       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.420416       0.37723
# 2022-03-02 23:00:00          0.408927       0.37723
# 2022-03-02 23:15:00          0.403949       0.37723
# 2022-03-02 23:30:00          0.400669       0.37723
# 2022-03-02 23:45:00          0.398888       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(GRU(64))
model.add(Dense(8, 'sigmoid'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_2 (GRU)                 (None, 64)                15744
#
#  dense_20 (Dense)            (None, 8)                 520
#
#  dense_21 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 16,273
# Trainable params: 16,273
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 169s 52ms/step - loss: 0.1544 - root_mean_squared_error: 0.3930 - val_loss: 0.0846 - val_root_mean_squared_error: 0.2909
# Epoch 2/10
# 3217/3217 [==============================] - 169s 53ms/step - loss: 0.0771 - root_mean_squared_error: 0.2777 - val_loss: 0.0713 - val_root_mean_squared_error: 0.2670
# Epoch 3/10
# 3217/3217 [==============================] - 165s 51ms/step - loss: 0.0705 - root_mean_squared_error: 0.2656 - val_loss: 0.0692 - val_root_mean_squared_error: 0.2631
# Epoch 4/10
# 3217/3217 [==============================] - 166s 52ms/step - loss: 0.0688 - root_mean_squared_error: 0.2624 - val_loss: 0.0671 - val_root_mean_squared_error: 0.2590
# Epoch 5/10
# 3217/3217 [==============================] - 166s 51ms/step - loss: 0.0680 - root_mean_squared_error: 0.2607 - val_loss: 0.0670 - val_root_mean_squared_error: 0.2588
# Epoch 6/10
# 3217/3217 [==============================] - 165s 51ms/step - loss: 0.0675 - root_mean_squared_error: 0.2597 - val_loss: 0.0659 - val_root_mean_squared_error: 0.2567
# Epoch 7/10
# 3217/3217 [==============================] - 164s 51ms/step - loss: 0.0671 - root_mean_squared_error: 0.2590 - val_loss: 0.0668 - val_root_mean_squared_error: 0.2584
# Epoch 8/10
# 3217/3217 [==============================] - 165s 51ms/step - loss: 0.0668 - root_mean_squared_error: 0.2584 - val_loss: 0.0660 - val_root_mean_squared_error: 0.2570
# Epoch 9/10
# 3217/3217 [==============================] - 167s 52ms/step - loss: 0.0667 - root_mean_squared_error: 0.2583 - val_loss: 0.0658 - val_root_mean_squared_error: 0.2566
# Epoch 10/10
# 3217/3217 [==============================] - 168s 52ms/step - loss: 0.0665 - root_mean_squared_error: 0.2578 - val_loss: 0.0649 - val_root_mean_squared_error: 0.2547
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.395479       0.33261
# 2021-09-27 01:15:00          0.353286       0.33261
# 2021-09-27 01:30:00          0.338710       0.31030
# 2021-09-27 01:45:00          0.318203       0.37723
# 2021-09-27 02:00:00          0.352038       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.406151       0.37723
# 2022-03-02 23:00:00          0.396160       0.37723
# 2022-03-02 23:15:00          0.389083       0.37723
# 2022-03-02 23:30:00          0.384785       0.37723
# 2022-03-02 23:45:00          0.381534       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(GRU(64))
model.add(Dense(8, 'selu'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_3 (GRU)                 (None, 64)                15744
#
#  dense_22 (Dense)            (None, 8)                 520
#
#  dense_23 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 16,273
# Trainable params: 16,273
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 164s 50ms/step - loss: 0.1642 - root_mean_squared_error: 0.4052 - val_loss: 0.0722 - val_root_mean_squared_error: 0.2688
# Epoch 2/10
# 3217/3217 [==============================] - 164s 51ms/step - loss: 0.0701 - root_mean_squared_error: 0.2648 - val_loss: 0.0729 - val_root_mean_squared_error: 0.2699
# Epoch 3/10
# 3217/3217 [==============================] - 163s 51ms/step - loss: 0.0689 - root_mean_squared_error: 0.2625 - val_loss: 0.0686 - val_root_mean_squared_error: 0.2618
# Epoch 4/10
# 3217/3217 [==============================] - 164s 51ms/step - loss: 0.0682 - root_mean_squared_error: 0.2611 - val_loss: 0.0693 - val_root_mean_squared_error: 0.2633
# Epoch 5/10
# 3217/3217 [==============================] - 163s 51ms/step - loss: 0.0677 - root_mean_squared_error: 0.2602 - val_loss: 0.0686 - val_root_mean_squared_error: 0.2619
# Epoch 6/10
# 3217/3217 [==============================] - 163s 51ms/step - loss: 0.0675 - root_mean_squared_error: 0.2598 - val_loss: 0.0663 - val_root_mean_squared_error: 0.2575
# Epoch 7/10
# 3217/3217 [==============================] - 164s 51ms/step - loss: 0.0672 - root_mean_squared_error: 0.2593 - val_loss: 0.0659 - val_root_mean_squared_error: 0.2567
# Epoch 8/10
# 3217/3217 [==============================] - 164s 51ms/step - loss: 0.0670 - root_mean_squared_error: 0.2588 - val_loss: 0.0666 - val_root_mean_squared_error: 0.2581
# Epoch 9/10
# 3217/3217 [==============================] - 163s 51ms/step - loss: 0.0667 - root_mean_squared_error: 0.2583 - val_loss: 0.0669 - val_root_mean_squared_error: 0.2586
# Epoch 10/10
# 3217/3217 [==============================] - 165s 51ms/step - loss: 0.0670 - root_mean_squared_error: 0.2588 - val_loss: 0.0666 - val_root_mean_squared_error: 0.2580
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.399212       0.33261
# 2021-09-27 01:15:00          0.355893       0.33261
# 2021-09-27 01:30:00          0.340831       0.31030
# 2021-09-27 01:45:00          0.322481       0.37723
# 2021-09-27 02:00:00          0.362395       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.399481       0.37723
# 2022-03-02 23:00:00          0.386189       0.37723
# 2022-03-02 23:15:00          0.379769       0.37723
# 2022-03-02 23:30:00          0.375888       0.37723
# 2022-03-02 23:45:00          0.373781       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(Conv1D(64, kernel_size=2))
model.add(Flatten())
model.add(Dense(8, 'relu'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 95, 64)            2112
#
#  flatten (Flatten)           (None, 6080)              0
#
#  dense_24 (Dense)            (None, 8)                 48648
#
#  dense_25 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 50,769
# Trainable params: 50,769
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 21s 6ms/step - loss: 0.3833 - root_mean_squared_error: 0.6191 - val_loss: 0.1663 - val_root_mean_squared_error: 0.4078
# Epoch 2/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.2038 - root_mean_squared_error: 0.4514 - val_loss: 0.1372 - val_root_mean_squared_error: 0.3705
# Epoch 3/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.1919 - root_mean_squared_error: 0.4381 - val_loss: 0.1736 - val_root_mean_squared_error: 0.4167
# Epoch 4/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.1717 - root_mean_squared_error: 0.4144 - val_loss: 0.1595 - val_root_mean_squared_error: 0.3993
# Epoch 5/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.1590 - root_mean_squared_error: 0.3987 - val_loss: 0.1301 - val_root_mean_squared_error: 0.3607
# Epoch 6/10
# 3217/3217 [==============================] - 21s 6ms/step - loss: 0.1493 - root_mean_squared_error: 0.3864 - val_loss: 0.1298 - val_root_mean_squared_error: 0.3603
# Epoch 7/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.1458 - root_mean_squared_error: 0.3819 - val_loss: 0.1274 - val_root_mean_squared_error: 0.3569
# Epoch 8/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.1424 - root_mean_squared_error: 0.3773 - val_loss: 0.1312 - val_root_mean_squared_error: 0.3622
# Epoch 9/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.1405 - root_mean_squared_error: 0.3749 - val_loss: 0.1252 - val_root_mean_squared_error: 0.3539
# Epoch 10/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.1371 - root_mean_squared_error: 0.3703 - val_loss: 0.1227 - val_root_mean_squared_error: 0.3503
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.311237       0.33261
# 2021-09-27 01:15:00          0.361373       0.33261
# 2021-09-27 01:30:00          0.387900       0.31030
# 2021-09-27 01:45:00          0.390087       0.37723
# 2021-09-27 02:00:00          0.379570       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.284560       0.37723
# 2022-03-02 23:00:00          0.278391       0.37723
# 2022-03-02 23:15:00          0.293376       0.37723
# 2022-03-02 23:30:00          0.275229       0.37723
# 2022-03-02 23:45:00          0.271261       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(Conv1D(64, kernel_size=2))
model.add(Flatten())
model.add(Dense(8, 'tanh'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 95, 64)            2112
#
#  flatten_1 (Flatten)         (None, 6080)              0
#
#  dense_26 (Dense)            (None, 8)                 48648
#
#  dense_27 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 50,769
# Trainable params: 50,769
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 22s 7ms/step - loss: 0.3981 - root_mean_squared_error: 0.6309 - val_loss: 0.2942 - val_root_mean_squared_error: 0.5424
# Epoch 2/10
# 3217/3217 [==============================] - 21s 7ms/step - loss: 0.2570 - root_mean_squared_error: 0.5070 - val_loss: 0.2214 - val_root_mean_squared_error: 0.4705
# Epoch 3/10
# 3217/3217 [==============================] - 21s 6ms/step - loss: 0.2122 - root_mean_squared_error: 0.4607 - val_loss: 0.1870 - val_root_mean_squared_error: 0.4325
# Epoch 4/10
# 3217/3217 [==============================] - 21s 7ms/step - loss: 0.1989 - root_mean_squared_error: 0.4460 - val_loss: 0.2180 - val_root_mean_squared_error: 0.4670
# Epoch 5/10
# 3217/3217 [==============================] - 21s 7ms/step - loss: 0.1892 - root_mean_squared_error: 0.4350 - val_loss: 0.1711 - val_root_mean_squared_error: 0.4136
# Epoch 6/10
# 3217/3217 [==============================] - 21s 7ms/step - loss: 0.1831 - root_mean_squared_error: 0.4279 - val_loss: 0.2714 - val_root_mean_squared_error: 0.5210
# Epoch 7/10
# 3217/3217 [==============================] - 21s 7ms/step - loss: 0.1817 - root_mean_squared_error: 0.4263 - val_loss: 0.1735 - val_root_mean_squared_error: 0.4165
# Epoch 8/10
# 3217/3217 [==============================] - 21s 7ms/step - loss: 0.1804 - root_mean_squared_error: 0.4247 - val_loss: 0.1927 - val_root_mean_squared_error: 0.4390
# Epoch 9/10
# 3217/3217 [==============================] - 21s 7ms/step - loss: 0.1785 - root_mean_squared_error: 0.4225 - val_loss: 0.2208 - val_root_mean_squared_error: 0.4699
# Epoch 10/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.1747 - root_mean_squared_error: 0.4180 - val_loss: 0.1772 - val_root_mean_squared_error: 0.4210
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.447849       0.33261
# 2021-09-27 01:15:00          0.447849       0.33261
# 2021-09-27 01:30:00          0.447849       0.31030
# 2021-09-27 01:45:00          0.447849       0.37723
# 2021-09-27 02:00:00          0.447849       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.447849       0.37723
# 2022-03-02 23:00:00          0.447849       0.37723
# 2022-03-02 23:15:00          0.447850       0.37723
# 2022-03-02 23:30:00          0.447851       0.37723
# 2022-03-02 23:45:00          0.447851       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(Conv1D(64, kernel_size=2))
model.add(Flatten())
model.add(Dense(8, 'sigmoid'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 95, 64)            2112
#
#  flatten_2 (Flatten)         (None, 6080)              0
#
#  dense_28 (Dense)            (None, 8)                 48648
#
#  dense_29 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 50,769
# Trainable params: 50,769
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 21s 6ms/step - loss: 0.2707 - root_mean_squared_error: 0.5203 - val_loss: 0.1942 - val_root_mean_squared_error: 0.4406
# Epoch 2/10
# 3217/3217 [==============================] - 21s 6ms/step - loss: 0.1833 - root_mean_squared_error: 0.4281 - val_loss: 0.1615 - val_root_mean_squared_error: 0.4019
# Epoch 3/10
# 3217/3217 [==============================] - 21s 6ms/step - loss: 0.1556 - root_mean_squared_error: 0.3945 - val_loss: 0.1393 - val_root_mean_squared_error: 0.3732
# Epoch 4/10
# 3217/3217 [==============================] - 21s 6ms/step - loss: 0.1383 - root_mean_squared_error: 0.3719 - val_loss: 0.1197 - val_root_mean_squared_error: 0.3460
# Epoch 5/10
# 3217/3217 [==============================] - 21s 6ms/step - loss: 0.1236 - root_mean_squared_error: 0.3516 - val_loss: 0.1092 - val_root_mean_squared_error: 0.3305
# Epoch 6/10
# 3217/3217 [==============================] - 22s 7ms/step - loss: 0.1182 - root_mean_squared_error: 0.3438 - val_loss: 0.1209 - val_root_mean_squared_error: 0.3477
# Epoch 7/10
# 3217/3217 [==============================] - 21s 6ms/step - loss: 0.1142 - root_mean_squared_error: 0.3380 - val_loss: 0.1093 - val_root_mean_squared_error: 0.3305
# Epoch 8/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.1103 - root_mean_squared_error: 0.3321 - val_loss: 0.1032 - val_root_mean_squared_error: 0.3213
# Epoch 9/10
# 3217/3217 [==============================] - 21s 7ms/step - loss: 0.1082 - root_mean_squared_error: 0.3290 - val_loss: 0.1019 - val_root_mean_squared_error: 0.3192
# Epoch 10/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.1033 - root_mean_squared_error: 0.3214 - val_loss: 0.1059 - val_root_mean_squared_error: 0.3254
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.376556       0.33261
# 2021-09-27 01:15:00          0.333831       0.33261
# 2021-09-27 01:30:00          0.330450       0.31030
# 2021-09-27 01:45:00          0.328092       0.37723
# 2021-09-27 02:00:00          0.368087       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.332635       0.37723
# 2022-03-02 23:00:00          0.347881       0.37723
# 2022-03-02 23:15:00          0.387710       0.37723
# 2022-03-02 23:30:00          0.365379       0.37723
# 2022-03-02 23:45:00          0.428574       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(Conv1D(64, kernel_size=2))
model.add(Flatten())
model.add(Dense(8, 'selu'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 95, 64)            2112
#
#  flatten_3 (Flatten)         (None, 6080)              0
#
#  dense_30 (Dense)            (None, 8)                 48648
#
#  dense_31 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 50,769
# Trainable params: 50,769
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 22s 7ms/step - loss: 0.5312 - root_mean_squared_error: 0.7288 - val_loss: 0.1288 - val_root_mean_squared_error: 0.3589
# Epoch 2/10
# 3217/3217 [==============================] - 22s 7ms/step - loss: 0.1888 - root_mean_squared_error: 0.4345 - val_loss: 0.1082 - val_root_mean_squared_error: 0.3289
# Epoch 3/10
# 3217/3217 [==============================] - 22s 7ms/step - loss: 0.1736 - root_mean_squared_error: 0.4167 - val_loss: 0.1499 - val_root_mean_squared_error: 0.3871
# Epoch 4/10
# 3217/3217 [==============================] - 21s 7ms/step - loss: 0.1464 - root_mean_squared_error: 0.3826 - val_loss: 0.1648 - val_root_mean_squared_error: 0.4060
# Epoch 5/10
# 3217/3217 [==============================] - 21s 6ms/step - loss: 0.1335 - root_mean_squared_error: 0.3654 - val_loss: 0.1043 - val_root_mean_squared_error: 0.3229
# Epoch 6/10
# 3217/3217 [==============================] - 21s 7ms/step - loss: 0.1240 - root_mean_squared_error: 0.3521 - val_loss: 0.1337 - val_root_mean_squared_error: 0.3656
# Epoch 7/10
# 3217/3217 [==============================] - 21s 7ms/step - loss: 0.1161 - root_mean_squared_error: 0.3408 - val_loss: 0.1073 - val_root_mean_squared_error: 0.3276
# Epoch 8/10
# 3217/3217 [==============================] - 21s 6ms/step - loss: 0.1097 - root_mean_squared_error: 0.3312 - val_loss: 0.1036 - val_root_mean_squared_error: 0.3219
# Epoch 9/10
# 3217/3217 [==============================] - 21s 7ms/step - loss: 0.1041 - root_mean_squared_error: 0.3226 - val_loss: 0.1815 - val_root_mean_squared_error: 0.4260
# Epoch 10/10
# 3217/3217 [==============================] - 21s 7ms/step - loss: 0.0980 - root_mean_squared_error: 0.3130 - val_loss: 0.0889 - val_root_mean_squared_error: 0.2981
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.458694       0.33261
# 2021-09-27 01:15:00          0.451156       0.33261
# 2021-09-27 01:30:00          0.415225       0.31030
# 2021-09-27 01:45:00          0.444133       0.37723
# 2021-09-27 02:00:00          0.423012       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.427600       0.37723
# 2022-03-02 23:00:00          0.408233       0.37723
# 2022-03-02 23:15:00          0.552680       0.37723
# 2022-03-02 23:30:00          0.360652       0.37723
# 2022-03-02 23:45:00          0.405036       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(LSTM(64, return_sequences=True))
model.add(Dropout(.2))
model.add(LSTM(32))

model.add(Dense(8, 'relu'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 96, 64)            20736
#
#  dropout (Dropout)           (None, 96, 64)            0
#
#  lstm_13 (LSTM)              (None, 32)                12416
#
#  dense_32 (Dense)            (None, 8)                 264
#
#  dense_33 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 33,425
# Trainable params: 33,425
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 320s 98ms/step - loss: 0.0838 - root_mean_squared_error: 0.2894 - val_loss: 0.0730 - val_root_mean_squared_error: 0.2701
# Epoch 2/10
# 3217/3217 [==============================] - 404s 125ms/step - loss: 0.0740 - root_mean_squared_error: 0.2720 - val_loss: 0.0736 - val_root_mean_squared_error: 0.2714
# Epoch 3/10
# 3217/3217 [==============================] - 372s 116ms/step - loss: 0.0723 - root_mean_squared_error: 0.2688 - val_loss: 0.0668 - val_root_mean_squared_error: 0.2586
# Epoch 4/10
# 3217/3217 [==============================] - 373s 116ms/step - loss: 0.0710 - root_mean_squared_error: 0.2666 - val_loss: 0.0667 - val_root_mean_squared_error: 0.2583
# Epoch 5/10
# 3217/3217 [==============================] - 372s 116ms/step - loss: 0.0707 - root_mean_squared_error: 0.2658 - val_loss: 0.0661 - val_root_mean_squared_error: 0.2572
# Epoch 6/10
# 3217/3217 [==============================] - 352s 109ms/step - loss: 0.0704 - root_mean_squared_error: 0.2653 - val_loss: 0.0750 - val_root_mean_squared_error: 0.2739
# Epoch 7/10
# 3217/3217 [==============================] - 370s 115ms/step - loss: 0.0696 - root_mean_squared_error: 0.2637 - val_loss: 0.0665 - val_root_mean_squared_error: 0.2579
# Epoch 8/10
# 3217/3217 [==============================] - 308s 96ms/step - loss: 0.0692 - root_mean_squared_error: 0.2632 - val_loss: 0.0687 - val_root_mean_squared_error: 0.2620
# Epoch 9/10
# 3217/3217 [==============================] - 308s 96ms/step - loss: 0.0689 - root_mean_squared_error: 0.2626 - val_loss: 0.0670 - val_root_mean_squared_error: 0.2589
# Epoch 10/10
# 3217/3217 [==============================] - 309s 96ms/step - loss: 0.0684 - root_mean_squared_error: 0.2615 - val_loss: 0.0650 - val_root_mean_squared_error: 0.2549
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.404579       0.33261
# 2021-09-27 01:15:00          0.362154       0.33261
# 2021-09-27 01:30:00          0.342933       0.31030
# 2021-09-27 01:45:00          0.319805       0.37723
# 2021-09-27 02:00:00          0.360749       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.400080       0.37723
# 2022-03-02 23:00:00          0.388439       0.37723
# 2022-03-02 23:15:00          0.382417       0.37723
# 2022-03-02 23:30:00          0.379836       0.37723
# 2022-03-02 23:45:00          0.378110       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(LSTM(64, return_sequences=True))
model.add(Dropout(.2))
model.add(LSTM(32))

model.add(Dense(8, 'tanh'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_14 (LSTM)              (None, 96, 64)            20736
#
#  dropout_1 (Dropout)         (None, 96, 64)            0
#
#  lstm_15 (LSTM)              (None, 32)                12416
#
#  dense_34 (Dense)            (None, 8)                 264
#
#  dense_35 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 33,425
# Trainable params: 33,425
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 334s 103ms/step - loss: 0.0862 - root_mean_squared_error: 0.2936 - val_loss: 0.0697 - val_root_mean_squared_error: 0.2641
# Epoch 2/10
# 3217/3217 [==============================] - 318s 99ms/step - loss: 0.0736 - root_mean_squared_error: 0.2714 - val_loss: 0.0699 - val_root_mean_squared_error: 0.2645
# Epoch 3/10
# 3217/3217 [==============================] - 321s 100ms/step - loss: 0.0721 - root_mean_squared_error: 0.2685 - val_loss: 0.0694 - val_root_mean_squared_error: 0.2634
# Epoch 4/10
# 3217/3217 [==============================] - 320s 99ms/step - loss: 0.0713 - root_mean_squared_error: 0.2671 - val_loss: 0.0682 - val_root_mean_squared_error: 0.2612
# Epoch 5/10
# 3217/3217 [==============================] - 319s 99ms/step - loss: 0.0705 - root_mean_squared_error: 0.2654 - val_loss: 0.0658 - val_root_mean_squared_error: 0.2565
# Epoch 6/10
# 3217/3217 [==============================] - 323s 100ms/step - loss: 0.0701 - root_mean_squared_error: 0.2648 - val_loss: 0.0706 - val_root_mean_squared_error: 0.2657
# Epoch 7/10
# 3217/3217 [==============================] - 321s 100ms/step - loss: 0.0695 - root_mean_squared_error: 0.2636 - val_loss: 0.0677 - val_root_mean_squared_error: 0.2602
# Epoch 8/10
# 3217/3217 [==============================] - 319s 99ms/step - loss: 0.0692 - root_mean_squared_error: 0.2630 - val_loss: 0.0666 - val_root_mean_squared_error: 0.2581
# Epoch 9/10
# 3217/3217 [==============================] - 319s 99ms/step - loss: 0.0695 - root_mean_squared_error: 0.2636 - val_loss: 0.0665 - val_root_mean_squared_error: 0.2578
# Epoch 10/10
# 3217/3217 [==============================] - 321s 100ms/step - loss: 0.0688 - root_mean_squared_error: 0.2623 - val_loss: 0.0671 - val_root_mean_squared_error: 0.2590
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.392677       0.33261
# 2021-09-27 01:15:00          0.346198       0.33261
# 2021-09-27 01:30:00          0.324099       0.31030
# 2021-09-27 01:45:00          0.296290       0.37723
# 2021-09-27 02:00:00          0.343538       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.389600       0.37723
# 2022-03-02 23:00:00          0.378805       0.37723
# 2022-03-02 23:15:00          0.370730       0.37723
# 2022-03-02 23:30:00          0.368025       0.37723
# 2022-03-02 23:45:00          0.366355       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(LSTM(64, return_sequences=True))
model.add(Dropout(.2))
model.add(LSTM(32))

model.add(Dense(8, 'sigmoid'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 96, 64)            20736
#
#  dropout (Dropout)           (None, 96, 64)            0
#
#  lstm_1 (LSTM)               (None, 32)                12416
#
#  dense (Dense)               (None, 8)                 264
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 33,425
# Trainable params: 33,425
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 300s 92ms/step - loss: 0.0965 - root_mean_squared_error: 0.3106 - val_loss: 0.0684 - val_root_mean_squared_error: 0.2615
# Epoch 2/10
# 3217/3217 [==============================] - 297s 92ms/step - loss: 0.0734 - root_mean_squared_error: 0.2709 - val_loss: 0.0682 - val_root_mean_squared_error: 0.2612
# Epoch 3/10
# 3217/3217 [==============================] - 297s 92ms/step - loss: 0.0718 - root_mean_squared_error: 0.2680 - val_loss: 0.0690 - val_root_mean_squared_error: 0.2627
# Epoch 4/10
# 3217/3217 [==============================] - 298s 93ms/step - loss: 0.0710 - root_mean_squared_error: 0.2664 - val_loss: 0.0660 - val_root_mean_squared_error: 0.2568
# Epoch 5/10
# 3217/3217 [==============================] - 324s 101ms/step - loss: 0.0710 - root_mean_squared_error: 0.2665 - val_loss: 0.0677 - val_root_mean_squared_error: 0.2602
# Epoch 6/10
# 3217/3217 [==============================] - 334s 104ms/step - loss: 0.0701 - root_mean_squared_error: 0.2647 - val_loss: 0.0679 - val_root_mean_squared_error: 0.2606
# Epoch 7/10
# 3217/3217 [==============================] - 300s 93ms/step - loss: 0.0700 - root_mean_squared_error: 0.2647 - val_loss: 0.0657 - val_root_mean_squared_error: 0.2564
# Epoch 8/10
# 3217/3217 [==============================] - 298s 93ms/step - loss: 0.0697 - root_mean_squared_error: 0.2640 - val_loss: 0.0654 - val_root_mean_squared_error: 0.2557
# Epoch 9/10
# 3217/3217 [==============================] - 300s 93ms/step - loss: 0.0693 - root_mean_squared_error: 0.2633 - val_loss: 0.0666 - val_root_mean_squared_error: 0.2581
# Epoch 10/10
# 3217/3217 [==============================] - 308s 96ms/step - loss: 0.0686 - root_mean_squared_error: 0.2619 - val_loss: 0.0669 - val_root_mean_squared_error: 0.2587
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.379108       0.33261
# 2021-09-27 01:15:00          0.340065       0.33261
# 2021-09-27 01:30:00          0.322974       0.31030
# 2021-09-27 01:45:00          0.303480       0.37723
# 2021-09-27 02:00:00          0.345338       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.375031       0.37723
# 2022-03-02 23:00:00          0.362809       0.37723
# 2022-03-02 23:15:00          0.358114       0.37723
# 2022-03-02 23:30:00          0.356769       0.37723
# 2022-03-02 23:45:00          0.356422       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(LSTM(64, return_sequences=True))
model.add(Dropout(.2))
model.add(LSTM(32))

model.add(Dense(8, 'selu'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 96, 64)            20736
#
#  dropout_1 (Dropout)         (None, 96, 64)            0
#
#  lstm_3 (LSTM)               (None, 32)                12416
#
#  dense_2 (Dense)             (None, 8)                 264
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 33,425
# Trainable params: 33,425
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 302s 92ms/step - loss: 0.0856 - root_mean_squared_error: 0.2925 - val_loss: 0.0724 - val_root_mean_squared_error: 0.2691
# Epoch 2/10
# 3217/3217 [==============================] - 306s 95ms/step - loss: 0.0741 - root_mean_squared_error: 0.2722 - val_loss: 0.0685 - val_root_mean_squared_error: 0.2618
# Epoch 3/10
# 3217/3217 [==============================] - 319s 99ms/step - loss: 0.0717 - root_mean_squared_error: 0.2678 - val_loss: 0.0685 - val_root_mean_squared_error: 0.2617
# Epoch 4/10
# 3217/3217 [==============================] - 307s 95ms/step - loss: 0.0710 - root_mean_squared_error: 0.2666 - val_loss: 0.0679 - val_root_mean_squared_error: 0.2606
# Epoch 5/10
# 3217/3217 [==============================] - 305s 95ms/step - loss: 0.0702 - root_mean_squared_error: 0.2649 - val_loss: 0.0668 - val_root_mean_squared_error: 0.2584
# Epoch 6/10
# 3217/3217 [==============================] - 305s 95ms/step - loss: 0.0697 - root_mean_squared_error: 0.2641 - val_loss: 0.0673 - val_root_mean_squared_error: 0.2595
# Epoch 7/10
# 3217/3217 [==============================] - 307s 95ms/step - loss: 0.0698 - root_mean_squared_error: 0.2641 - val_loss: 0.0664 - val_root_mean_squared_error: 0.2578
# Epoch 8/10
# 3217/3217 [==============================] - 313s 97ms/step - loss: 0.0693 - root_mean_squared_error: 0.2633 - val_loss: 0.0708 - val_root_mean_squared_error: 0.2661
# Epoch 9/10
# 3217/3217 [==============================] - 307s 96ms/step - loss: 0.0687 - root_mean_squared_error: 0.2621 - val_loss: 0.0659 - val_root_mean_squared_error: 0.2567
# Epoch 10/10
# 3217/3217 [==============================] - 309s 96ms/step - loss: 0.0688 - root_mean_squared_error: 0.2623 - val_loss: 0.0674 - val_root_mean_squared_error: 0.2597
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.399193       0.33261
# 2021-09-27 01:15:00          0.352823       0.33261
# 2021-09-27 01:30:00          0.337313       0.31030
# 2021-09-27 01:45:00          0.321742       0.37723
# 2021-09-27 02:00:00          0.374029       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.394427       0.37723
# 2022-03-02 23:00:00          0.381032       0.37723
# 2022-03-02 23:15:00          0.376715       0.37723
# 2022-03-02 23:30:00          0.377190       0.37723
# 2022-03-02 23:45:00          0.377574       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(SimpleRNN(128, return_sequences=True))
model.add(LSTM(64, return_sequences=True))
model.add(Dropout(.2))
model.add(LSTM(32))
model.add(Dense(8, 'relu'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 96, 128)           18560
#
#  lstm_4 (LSTM)               (None, 96, 64)            49408
#
#  dropout_2 (Dropout)         (None, 96, 64)            0
#
#  lstm_5 (LSTM)               (None, 32)                12416
#
#  dense_4 (Dense)             (None, 8)                 264
#
#  dense_5 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 80,657
# Trainable params: 80,657
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 477s 147ms/step - loss: 0.0825 - root_mean_squared_error: 0.2872 - val_loss: 0.0787 - val_root_mean_squared_error: 0.2805
# Epoch 2/10
# 3217/3217 [==============================] - 525s 163ms/step - loss: 0.0744 - root_mean_squared_error: 0.2728 - val_loss: 0.0695 - val_root_mean_squared_error: 0.2635
# Epoch 3/10
# 3217/3217 [==============================] - 450s 140ms/step - loss: 0.0741 - root_mean_squared_error: 0.2722 - val_loss: 0.0727 - val_root_mean_squared_error: 0.2695
# Epoch 4/10
# 3217/3217 [==============================] - 452s 140ms/step - loss: 0.0728 - root_mean_squared_error: 0.2698 - val_loss: 0.0689 - val_root_mean_squared_error: 0.2625
# Epoch 5/10
# 3217/3217 [==============================] - 451s 140ms/step - loss: 0.0718 - root_mean_squared_error: 0.2679 - val_loss: 0.0690 - val_root_mean_squared_error: 0.2627
# Epoch 6/10
# 3217/3217 [==============================] - 450s 140ms/step - loss: 0.0709 - root_mean_squared_error: 0.2662 - val_loss: 0.0716 - val_root_mean_squared_error: 0.2676
# Epoch 7/10
# 3217/3217 [==============================] - 510s 159ms/step - loss: 0.0709 - root_mean_squared_error: 0.2664 - val_loss: 0.0687 - val_root_mean_squared_error: 0.2622
# Epoch 8/10
# 3217/3217 [==============================] - 545s 169ms/step - loss: 0.0705 - root_mean_squared_error: 0.2655 - val_loss: 0.0685 - val_root_mean_squared_error: 0.2617
# Epoch 9/10
# 3217/3217 [==============================] - 522s 162ms/step - loss: 0.0702 - root_mean_squared_error: 0.2649 - val_loss: 0.0684 - val_root_mean_squared_error: 0.2615
# Epoch 10/10
# 3217/3217 [==============================] - 513s 159ms/step - loss: 0.0700 - root_mean_squared_error: 0.2645 - val_loss: 0.0684 - val_root_mean_squared_error: 0.2615
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.386050       0.33261
# 2021-09-27 01:15:00          0.334851       0.33261
# 2021-09-27 01:30:00          0.315254       0.31030
# 2021-09-27 01:45:00          0.301257       0.37723
# 2021-09-27 02:00:00          0.354193       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.381649       0.37723
# 2022-03-02 23:00:00          0.363090       0.37723
# 2022-03-02 23:15:00          0.366513       0.37723
# 2022-03-02 23:30:00          0.363090       0.37723
# 2022-03-02 23:45:00          0.356579       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(SimpleRNN(128, return_sequences=True))
model.add(LSTM(64, return_sequences=True))
model.add(Dropout(.2))
model.add(LSTM(32))
model.add(Dense(8, 'tanh'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 96, 128)           18560
#
#  lstm_6 (LSTM)               (None, 96, 64)            49408
#
#  dropout_3 (Dropout)         (None, 96, 64)            0
#
#  lstm_7 (LSTM)               (None, 32)                12416
#
#  dense_6 (Dense)             (None, 8)                 264
#
#  dense_7 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 80,657
# Trainable params: 80,657
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 527s 162ms/step - loss: 0.0863 - root_mean_squared_error: 0.2937 - val_loss: 0.0770 - val_root_mean_squared_error: 0.2776
# Epoch 2/10
# 3217/3217 [==============================] - 508s 158ms/step - loss: 0.0754 - root_mean_squared_error: 0.2746 - val_loss: 0.0713 - val_root_mean_squared_error: 0.2670
# Epoch 3/10
# 3217/3217 [==============================] - 498s 155ms/step - loss: 0.0741 - root_mean_squared_error: 0.2722 - val_loss: 0.0679 - val_root_mean_squared_error: 0.2605
# Epoch 4/10
# 3217/3217 [==============================] - 472s 147ms/step - loss: 0.0728 - root_mean_squared_error: 0.2698 - val_loss: 0.0704 - val_root_mean_squared_error: 0.2653
# Epoch 5/10
# 3217/3217 [==============================] - 505s 157ms/step - loss: 0.0723 - root_mean_squared_error: 0.2689 - val_loss: 0.0723 - val_root_mean_squared_error: 0.2690
# Epoch 6/10
# 3217/3217 [==============================] - 512s 159ms/step - loss: 0.0719 - root_mean_squared_error: 0.2682 - val_loss: 0.0697 - val_root_mean_squared_error: 0.2640
# Epoch 7/10
# 3217/3217 [==============================] - 515s 160ms/step - loss: 0.0714 - root_mean_squared_error: 0.2672 - val_loss: 0.0684 - val_root_mean_squared_error: 0.2615
# Epoch 8/10
# 3217/3217 [==============================] - 533s 166ms/step - loss: 0.0705 - root_mean_squared_error: 0.2655 - val_loss: 0.0687 - val_root_mean_squared_error: 0.2621
# Epoch 9/10
# 3217/3217 [==============================] - 464s 144ms/step - loss: 0.0704 - root_mean_squared_error: 0.2654 - val_loss: 0.0727 - val_root_mean_squared_error: 0.2696
# Epoch 10/10
# 3217/3217 [==============================] - 452s 141ms/step - loss: 0.0706 - root_mean_squared_error: 0.2657 - val_loss: 0.0708 - val_root_mean_squared_error: 0.2661
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.388496       0.33261
# 2021-09-27 01:15:00          0.346619       0.33261
# 2021-09-27 01:30:00          0.333409       0.31030
# 2021-09-27 01:45:00          0.320982       0.37723
# 2021-09-27 02:00:00          0.365573       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.385749       0.37723
# 2022-03-02 23:00:00          0.366387       0.37723
# 2022-03-02 23:15:00          0.374803       0.37723
# 2022-03-02 23:30:00          0.369347       0.37723
# 2022-03-02 23:45:00          0.364726       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(SimpleRNN(128, return_sequences=True))
model.add(LSTM(64, return_sequences=True))
model.add(Dropout(.2))
model.add(LSTM(32))
model.add(Dense(8, 'sigmoid'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_2 (SimpleRNN)    (None, 96, 128)           18560
#
#  lstm_8 (LSTM)               (None, 96, 64)            49408
#
#  dropout_4 (Dropout)         (None, 96, 64)            0
#
#  lstm_9 (LSTM)               (None, 32)                12416
#
#  dense_8 (Dense)             (None, 8)                 264
#
#  dense_9 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 80,657
# Trainable params: 80,657
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 488s 150ms/step - loss: 0.0876 - root_mean_squared_error: 0.2960 - val_loss: 0.0728 - val_root_mean_squared_error: 0.2699
# Epoch 2/10
# 3217/3217 [==============================] - 463s 144ms/step - loss: 0.0742 - root_mean_squared_error: 0.2725 - val_loss: 0.0711 - val_root_mean_squared_error: 0.2666
# Epoch 3/10
# 3217/3217 [==============================] - 458s 142ms/step - loss: 0.0731 - root_mean_squared_error: 0.2703 - val_loss: 0.0806 - val_root_mean_squared_error: 0.2838
# Epoch 4/10
# 3217/3217 [==============================] - 455s 141ms/step - loss: 0.0728 - root_mean_squared_error: 0.2698 - val_loss: 0.0701 - val_root_mean_squared_error: 0.2648
# Epoch 5/10
# 3217/3217 [==============================] - 464s 144ms/step - loss: 0.0718 - root_mean_squared_error: 0.2680 - val_loss: 0.0702 - val_root_mean_squared_error: 0.2650
# Epoch 6/10
# 3217/3217 [==============================] - 463s 144ms/step - loss: 0.0713 - root_mean_squared_error: 0.2670 - val_loss: 0.0691 - val_root_mean_squared_error: 0.2628
# Epoch 7/10
# 3217/3217 [==============================] - 463s 144ms/step - loss: 0.0707 - root_mean_squared_error: 0.2659 - val_loss: 0.0728 - val_root_mean_squared_error: 0.2699
# Epoch 8/10
# 3217/3217 [==============================] - 466s 145ms/step - loss: 0.0702 - root_mean_squared_error: 0.2650 - val_loss: 0.0681 - val_root_mean_squared_error: 0.2610
# Epoch 9/10
# 3217/3217 [==============================] - 485s 151ms/step - loss: 0.0698 - root_mean_squared_error: 0.2642 - val_loss: 0.0683 - val_root_mean_squared_error: 0.2613
# Epoch 10/10
# 3217/3217 [==============================] - 471s 146ms/step - loss: 0.0694 - root_mean_squared_error: 0.2635 - val_loss: 0.0686 - val_root_mean_squared_error: 0.2619
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.398313       0.33261
# 2021-09-27 01:15:00          0.353009       0.33261
# 2021-09-27 01:30:00          0.335953       0.31030
# 2021-09-27 01:45:00          0.320367       0.37723
# 2021-09-27 02:00:00          0.365348       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.375105       0.37723
# 2022-03-02 23:00:00          0.372414       0.37723
# 2022-03-02 23:15:00          0.381120       0.37723
# 2022-03-02 23:30:00          0.375471       0.37723
# 2022-03-02 23:45:00          0.379690       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(SimpleRNN(128, return_sequences=True))
model.add(LSTM(64, return_sequences=True))
model.add(Dropout(.2))
model.add(LSTM(32))
model.add(Dense(8, 'selu'))
model.add(Dense(output_size, 'linear'))

model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_3 (SimpleRNN)    (None, 96, 128)           18560
#
#  lstm_10 (LSTM)              (None, 96, 64)            49408
#
#  dropout_5 (Dropout)         (None, 96, 64)            0
#
#  lstm_11 (LSTM)              (None, 32)                12416
#
#  dense_10 (Dense)            (None, 8)                 264
#
#  dense_11 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 80,657
# Trainable params: 80,657
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 483s 148ms/step - loss: 0.0855 - root_mean_squared_error: 0.2923 - val_loss: 0.0751 - val_root_mean_squared_error: 0.2741
# Epoch 2/10
# 3217/3217 [==============================] - 456s 142ms/step - loss: 0.0758 - root_mean_squared_error: 0.2752 - val_loss: 0.0692 - val_root_mean_squared_error: 0.2631
# Epoch 3/10
# 3217/3217 [==============================] - 454s 141ms/step - loss: 0.0738 - root_mean_squared_error: 0.2716 - val_loss: 0.0701 - val_root_mean_squared_error: 0.2648
# Epoch 4/10
# 3217/3217 [==============================] - 454s 141ms/step - loss: 0.0732 - root_mean_squared_error: 0.2705 - val_loss: 0.0707 - val_root_mean_squared_error: 0.2659
# Epoch 5/10
# 3217/3217 [==============================] - 458s 142ms/step - loss: 0.0725 - root_mean_squared_error: 0.2693 - val_loss: 0.0686 - val_root_mean_squared_error: 0.2620
# Epoch 6/10
# 3217/3217 [==============================] - 575s 179ms/step - loss: 0.0720 - root_mean_squared_error: 0.2683 - val_loss: 0.0688 - val_root_mean_squared_error: 0.2622
# Epoch 7/10
# 3217/3217 [==============================] - 460s 143ms/step - loss: 0.0709 - root_mean_squared_error: 0.2663 - val_loss: 0.0676 - val_root_mean_squared_error: 0.2599
# Epoch 8/10
# 3217/3217 [==============================] - 460s 143ms/step - loss: 0.0715 - root_mean_squared_error: 0.2674 - val_loss: 0.0729 - val_root_mean_squared_error: 0.2701
# Epoch 9/10
# 3217/3217 [==============================] - 460s 143ms/step - loss: 0.0707 - root_mean_squared_error: 0.2659 - val_loss: 0.0786 - val_root_mean_squared_error: 0.2804
# Epoch 10/10
# 3217/3217 [==============================] - 461s 143ms/step - loss: 0.0712 - root_mean_squared_error: 0.2669 - val_loss: 0.0708 - val_root_mean_squared_error: 0.2662
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.379405       0.33261
# 2021-09-27 01:15:00          0.339989       0.33261
# 2021-09-27 01:30:00          0.328953       0.31030
# 2021-09-27 01:45:00          0.308133       0.37723
# 2021-09-27 02:00:00          0.344951       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.376285       0.37723
# 2022-03-02 23:00:00          0.368908       0.37723
# 2022-03-02 23:15:00          0.353914       0.37723
# 2022-03-02 23:30:00          0.357601       0.37723
# 2022-03-02 23:45:00          0.351478       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(Conv1D(64, kernel_size=2))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(8, 'relu'))
model.add(Dense(output_size, 'linear'))
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 95, 64)            2112
#
#  max_pooling1d (MaxPooling1D  (None, 47, 64)           0
#  )
#
#  flatten (Flatten)           (None, 3008)              0
#
#  dense_12 (Dense)            (None, 8)                 24072
#
#  dense_13 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 26,193
# Trainable params: 26,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.5739 - root_mean_squared_error: 0.7576 - val_loss: 0.1717 - val_root_mean_squared_error: 0.4144
# Epoch 2/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.1718 - root_mean_squared_error: 0.4144 - val_loss: 0.1663 - val_root_mean_squared_error: 0.4078
# Epoch 3/10
# 3217/3217 [==============================] - 21s 6ms/step - loss: 0.1670 - root_mean_squared_error: 0.4087 - val_loss: 0.1577 - val_root_mean_squared_error: 0.3971
# Epoch 4/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.1643 - root_mean_squared_error: 0.4054 - val_loss: 0.1466 - val_root_mean_squared_error: 0.3829
# Epoch 5/10
# 3217/3217 [==============================] - 21s 7ms/step - loss: 0.1610 - root_mean_squared_error: 0.4012 - val_loss: 0.1479 - val_root_mean_squared_error: 0.3846
# Epoch 6/10
# 3217/3217 [==============================] - 19s 6ms/step - loss: 0.1575 - root_mean_squared_error: 0.3969 - val_loss: 0.1429 - val_root_mean_squared_error: 0.3780
# Epoch 7/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.1481 - root_mean_squared_error: 0.3848 - val_loss: 0.1231 - val_root_mean_squared_error: 0.3509
# Epoch 8/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.1234 - root_mean_squared_error: 0.3513 - val_loss: 0.1151 - val_root_mean_squared_error: 0.3393
# Epoch 9/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.1184 - root_mean_squared_error: 0.3441 - val_loss: 0.1119 - val_root_mean_squared_error: 0.3346
# Epoch 10/10
# 3217/3217 [==============================] - 21s 7ms/step - loss: 0.1178 - root_mean_squared_error: 0.3432 - val_loss: 0.1159 - val_root_mean_squared_error: 0.3405
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.466797       0.33261
# 2021-09-27 01:15:00          0.466797       0.33261
# 2021-09-27 01:30:00          0.466797       0.31030
# 2021-09-27 01:45:00          0.466797       0.37723
# 2021-09-27 02:00:00          0.466797       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.466797       0.37723
# 2022-03-02 23:00:00          0.466797       0.37723
# 2022-03-02 23:15:00          0.466797       0.37723
# 2022-03-02 23:30:00          0.466797       0.37723
# 2022-03-02 23:45:00          0.466797       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(Conv1D(64, kernel_size=2))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(8, 'tanh'))
model.add(Dense(output_size, 'linear'))
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 95, 64)            2112
#
#  max_pooling1d_1 (MaxPooling  (None, 47, 64)           0
#  1D)
#
#  flatten_1 (Flatten)         (None, 3008)              0
#
#  dense_14 (Dense)            (None, 8)                 24072
#
#  dense_15 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 26,193
# Trainable params: 26,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.2498 - root_mean_squared_error: 0.4998 - val_loss: 0.1738 - val_root_mean_squared_error: 0.4169
# Epoch 2/10
# 3217/3217 [==============================] - 19s 6ms/step - loss: 0.1648 - root_mean_squared_error: 0.4060 - val_loss: 0.1795 - val_root_mean_squared_error: 0.4236
# Epoch 3/10
# 3217/3217 [==============================] - 19s 6ms/step - loss: 0.1505 - root_mean_squared_error: 0.3879 - val_loss: 0.1407 - val_root_mean_squared_error: 0.3751
# Epoch 4/10
# 3217/3217 [==============================] - 18s 6ms/step - loss: 0.1477 - root_mean_squared_error: 0.3843 - val_loss: 0.1576 - val_root_mean_squared_error: 0.3970
# Epoch 5/10
# 3217/3217 [==============================] - 19s 6ms/step - loss: 0.1417 - root_mean_squared_error: 0.3764 - val_loss: 0.1315 - val_root_mean_squared_error: 0.3626
# Epoch 6/10
# 3217/3217 [==============================] - 19s 6ms/step - loss: 0.1390 - root_mean_squared_error: 0.3729 - val_loss: 0.1400 - val_root_mean_squared_error: 0.3742
# Epoch 7/10
# 3217/3217 [==============================] - 19s 6ms/step - loss: 0.1344 - root_mean_squared_error: 0.3666 - val_loss: 0.1329 - val_root_mean_squared_error: 0.3645
# Epoch 8/10
# 3217/3217 [==============================] - 19s 6ms/step - loss: 0.1333 - root_mean_squared_error: 0.3651 - val_loss: 0.1492 - val_root_mean_squared_error: 0.3862
# Epoch 9/10
# 3217/3217 [==============================] - 19s 6ms/step - loss: 0.1317 - root_mean_squared_error: 0.3630 - val_loss: 0.1305 - val_root_mean_squared_error: 0.3612
# Epoch 10/10
# 3217/3217 [==============================] - 19s 6ms/step - loss: 0.1362 - root_mean_squared_error: 0.3691 - val_loss: 0.1340 - val_root_mean_squared_error: 0.3661
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.366491       0.33261
# 2021-09-27 01:15:00          0.366520       0.33261
# 2021-09-27 01:30:00          0.364332       0.31030
# 2021-09-27 01:45:00          0.363753       0.37723
# 2021-09-27 02:00:00          0.363705       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.365842       0.37723
# 2022-03-02 23:00:00          0.369657       0.37723
# 2022-03-02 23:15:00          0.364500       0.37723
# 2022-03-02 23:30:00          0.364958       0.37723
# 2022-03-02 23:45:00          0.371580       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(Conv1D(64, kernel_size=2))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(8, 'sigmoid'))
model.add(Dense(output_size, 'linear'))
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 95, 64)            2112
#
#  max_pooling1d_2 (MaxPooling  (None, 47, 64)           0
#  1D)
#
#  flatten_2 (Flatten)         (None, 3008)              0
#
#  dense_16 (Dense)            (None, 8)                 24072
#
#  dense_17 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 26,193
# Trainable params: 26,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 21s 6ms/step - loss: 0.2363 - root_mean_squared_error: 0.4861 - val_loss: 0.1705 - val_root_mean_squared_error: 0.4129
# Epoch 2/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.1545 - root_mean_squared_error: 0.3931 - val_loss: 0.1418 - val_root_mean_squared_error: 0.3766
# Epoch 3/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.1456 - root_mean_squared_error: 0.3816 - val_loss: 0.1489 - val_root_mean_squared_error: 0.3858
# Epoch 4/10
# 3217/3217 [==============================] - 19s 6ms/step - loss: 0.1366 - root_mean_squared_error: 0.3696 - val_loss: 0.1316 - val_root_mean_squared_error: 0.3628
# Epoch 5/10
# 3217/3217 [==============================] - 19s 6ms/step - loss: 0.1305 - root_mean_squared_error: 0.3612 - val_loss: 0.1286 - val_root_mean_squared_error: 0.3586
# Epoch 6/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.1273 - root_mean_squared_error: 0.3568 - val_loss: 0.1233 - val_root_mean_squared_error: 0.3511
# Epoch 7/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.1314 - root_mean_squared_error: 0.3625 - val_loss: 0.1328 - val_root_mean_squared_error: 0.3645
# Epoch 8/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.1245 - root_mean_squared_error: 0.3528 - val_loss: 0.1225 - val_root_mean_squared_error: 0.3500
# Epoch 9/10
# 3217/3217 [==============================] - 20s 6ms/step - loss: 0.1210 - root_mean_squared_error: 0.3479 - val_loss: 0.1172 - val_root_mean_squared_error: 0.3424
# Epoch 10/10
# 3217/3217 [==============================] - 19s 6ms/step - loss: 0.1241 - root_mean_squared_error: 0.3523 - val_loss: 0.1280 - val_root_mean_squared_error: 0.3577
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.389762       0.33261
# 2021-09-27 01:15:00          0.362427       0.33261
# 2021-09-27 01:30:00          0.360318       0.31030
# 2021-09-27 01:45:00          0.342154       0.37723
# 2021-09-27 02:00:00          0.328943       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.336712       0.37723
# 2022-03-02 23:00:00          0.339993       0.37723
# 2022-03-02 23:15:00          0.350565       0.37723
# 2022-03-02 23:30:00          0.363971       0.37723
# 2022-03-02 23:45:00          0.340698       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]

# %%
model = Sequential()
model.add(InputLayer(input_size))
model.add(Conv1D(64, kernel_size=2))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(8, 'selu'))
model.add(Dense(output_size, 'linear'))
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

model.summary()

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10)

plot_predictions(model, X_test, y_test, y_test_df)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 95, 64)            2112
#
#  max_pooling1d_3 (MaxPooling  (None, 47, 64)           0
#  1D)
#
#  flatten_3 (Flatten)         (None, 3008)              0
#
#  dense_18 (Dense)            (None, 8)                 24072
#
#  dense_19 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 26,193
# Trainable params: 26,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3217/3217 [==============================] - 24s 7ms/step - loss: 0.4724 - root_mean_squared_error: 0.6873 - val_loss: 0.1981 - val_root_mean_squared_error: 0.4451
# Epoch 2/10
# 3217/3217 [==============================] - 23s 7ms/step - loss: 0.1656 - root_mean_squared_error: 0.4070 - val_loss: 0.1331 - val_root_mean_squared_error: 0.3648
# Epoch 3/10
# 3217/3217 [==============================] - 23s 7ms/step - loss: 0.1335 - root_mean_squared_error: 0.3654 - val_loss: 0.1604 - val_root_mean_squared_error: 0.4006
# Epoch 4/10
# 3217/3217 [==============================] - 23s 7ms/step - loss: 0.1242 - root_mean_squared_error: 0.3524 - val_loss: 0.1490 - val_root_mean_squared_error: 0.3860
# Epoch 5/10
# 3217/3217 [==============================] - 23s 7ms/step - loss: 0.1191 - root_mean_squared_error: 0.3451 - val_loss: 0.1290 - val_root_mean_squared_error: 0.3592
# Epoch 6/10
# 3217/3217 [==============================] - 24s 7ms/step - loss: 0.1169 - root_mean_squared_error: 0.3418 - val_loss: 0.1120 - val_root_mean_squared_error: 0.3346
# Epoch 7/10
# 3217/3217 [==============================] - 23s 7ms/step - loss: 0.1132 - root_mean_squared_error: 0.3365 - val_loss: 0.1695 - val_root_mean_squared_error: 0.4117
# Epoch 8/10
# 3217/3217 [==============================] - 23s 7ms/step - loss: 0.1136 - root_mean_squared_error: 0.3370 - val_loss: 0.1192 - val_root_mean_squared_error: 0.3452
# Epoch 9/10
# 3217/3217 [==============================] - 23s 7ms/step - loss: 0.1103 - root_mean_squared_error: 0.3321 - val_loss: 0.1211 - val_root_mean_squared_error: 0.3480
# Epoch 10/10
# 3217/3217 [==============================] - 23s 7ms/step - loss: 0.1087 - root_mean_squared_error: 0.3297 - val_loss: 0.1329 - val_root_mean_squared_error: 0.3646
#                      PM10 predictions  PM10 actuals  \
# date_time
# 2021-09-27 01:00:00          0.549422       0.33261
# 2021-09-27 01:15:00          0.541314       0.33261
# 2021-09-27 01:30:00          0.542227       0.31030
# 2021-09-27 01:45:00          0.510277       0.37723
# 2021-09-27 02:00:00          0.497143       0.37723
# ...                               ...           ...
# 2022-03-02 22:45:00          0.427552       0.37723
# 2022-03-02 23:00:00          0.501556       0.37723
# 2022-03-02 23:15:00          0.413897       0.37723
# 2022-03-02 23:30:00          0.476869       0.37723
# 2022-03-02 23:45:00          0.495774       0.31030
#
#                                                 sensor_id        log  \
# date_time
# 2021-09-27 01:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 01:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2021-09-27 02:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# ...                                                   ...        ...
# 2022-03-02 22:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:00:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:15:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:30:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
# 2022-03-02 23:45:00  200cdb67-8dc5-4dcf-ac62-748db636e04e  21.456479
#
#                            lat  Year       YM
# date_time
# 2021-09-27 01:00:00  41.975155  2021  2021-09
# 2021-09-27 01:15:00  41.975155  2021  2021-09
# 2021-09-27 01:30:00  41.975155  2021  2021-09
# 2021-09-27 01:45:00  41.975155  2021  2021-09
# 2021-09-27 02:00:00  41.975155  2021  2021-09
# ...                        ...   ...      ...
# 2022-03-02 22:45:00  41.975155  2022  2022-03
# 2022-03-02 23:00:00  41.975155  2022  2022-03
# 2022-03-02 23:15:00  41.975155  2022  2022-03
# 2022-03-02 23:30:00  41.975155  2022  2022-03
# 2022-03-02 23:45:00  41.975155  2022  2022-03
#
# [14704 rows x 7 columns]
